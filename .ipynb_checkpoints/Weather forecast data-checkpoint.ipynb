# %%
import requests as req
import pandas as pd
import json
import re

# %%
# reading wiki Table of cities in india by population
wiki_tab = pd.read_html('https://en.wikipedia.org/wiki/List_of_cities_in_India_by_population')

# %%
print (wiki_tab)
# Out:
# [        0                    1                    2                 3  \
# 0    Rank                 City  Population(2011)[3]  Population(2001)
# 1       1               Mumbai             12442373          11978450
# 2       2                Delhi             11007835           9879172
# 3       3            Bangalore              8436675           6537124
# 4       4            Hyderabad              6809970           3637483
# 5       5            Ahmedabad              5570585           3520085
# 6       6              Chennai              4681087           4343645
# 7       7              Kolkata              4486679           4301326
# 8       8                Surat              4467797           2433835
# 9       9                 Pune              3124458           2538473
# 10     10               Jaipur              3046163           2322575
# 11     11              Lucknow              2817105           2185927
# 12     12               Kanpur              2765348           2551337
# 13     13               Nagpur              2405665           2052066
# 14     14               Indore              1964086           1474968
# 15     15                Thane              1841488           1262551
# 16     16               Bhopal              1798218           1437354
# 17     17  Visakhapatnam[a][5]              1728128            982904
# 18     18     Pimpri-Chinchwad              1727692           1012472
# 19     19                Patna              1684222           1366444
# 20     20             Vadodara              1670806           1306227
# 21     21            Ghaziabad              1648643            968256
# 22     22             Ludhiana              1618879           1398467
# 23     23                 Agra              1585704           1275134
# 24     24               Nashik              1486053           1077236
# 25     25            Faridabad              1414050           1055938
# 26     26               Meerut              1305429           1039405
# 27     27               Rajkot              1286678            967476
# 28     28      Kalyan-Dombivli              1247327           1193512
# 29     29          Vasai-Virar              1222390            693350
# ..    ...                  ...                  ...               ...
# 270   270          Saharsa[21]               155175            125167
# 271   271             Hindupur               151835                 ―
# 272   272          Sasaram[22]               147396            131172
# 273   273          Hajipur[23]               147126            119412
# 274   274           Bhimavaram               142280                 ―
# 275   275           Kumbakonam               140056            144021
# 276   276            Dehri[22]               137068            119057
# 277   277          Madanapalle               135669                 ―
# 278   278            Siwan[24]               134458            109919
# 279   279          Bettiah[25]               132896            116670
# 280   280             Guntakal               126270                 ―
# 281   281           Srikakulam               125939                 ―
# 282   282         Motihari[26]               125183            100683
# 283   283          Dharmavaram               121874                 ―
# 284   284             Gudivada               118167                 ―
# 285   285             Phagwara               117966                 ―
# 286   286         Narasaraopet               116250                 ―
# 287   287             Suryapet               115250             94585
# 288   288          Miryalaguda               109891             91395
# 289   289            Tadipatri               108171                 ―
# 290   290       Kishanganj[27]               107076             85590
# 291   291            Karaikudi               106714             86596
# 292   292         Jamalpur[28]               105221             96983
# 293   293               Kavali               104000                 ―
# 294   294       Tadepalligudem               103906                 ―
# 295   295            Amaravati               103000                 ―
# 296   296            Buxar[29]               102591             83168
# 297   297        Jehanabad[30]               102456             81503
# 298   298       Aurangabad[31]               101520             79393
# 299   299              Gangtok               100286             29354
#
#                             4
# 0    State or union territory
# 1                 Maharashtra
# 2                       Delhi
# 3                   Karnataka
# 4                   Telangana
# 5                     Gujarat
# 6                  Tamil Nadu
# 7                 West Bengal
# 8                     Gujarat
# 9                 Maharashtra
# 10                  Rajasthan
# 11              Uttar Pradesh
# 12              Uttar Pradesh
# 13                Maharashtra
# 14             Madhya Pradesh
# 15                Maharashtra
# 16             Madhya Pradesh
# 17             Andhra Pradesh
# 18                Maharashtra
# 19                      Bihar
# 20                    Gujarat
# 21              Uttar Pradesh
# 22                     Punjab
# 23              Uttar Pradesh
# 24                Maharashtra
# 25                    Haryana
# 26              Uttar Pradesh
# 27                    Gujarat
# 28                Maharashtra
# 29                Maharashtra
# ..                        ...
# 270                     Bihar
# 271            Andhra Pradesh
# 272                     Bihar
# 273                     Bihar
# 274            Andhra Pradesh
# 275                Tamil Nadu
# 276                     Bihar
# 277            Andhra Pradesh
# 278                     Bihar
# 279                     Bihar
# 280            Andhra Pradesh
# 281            Andhra Pradesh
# 282                     Bihar
# 283            Andhra Pradesh
# 284            Andhra Pradesh
# 285                    Punjab
# 286            Andhra Pradesh
# 287                 Telangana
# 288                 Telangana
# 289            Andhra Pradesh
# 290                     Bihar
# 291                Tamil Nadu
# 292                     Bihar
# 293            Andhra Pradesh
# 294            Andhra Pradesh
# 295            Andhra Pradesh
# 296                     Bihar
# 297                     Bihar
# 298                     Bihar
# 299                    Sikkim
#
# [300 rows x 5 columns],                                   0  \
# 0  vtePopulation of cities in India
# 1         States/ Union Territories
# 2                     Related lists
#
#                                                    1
# 0                                                NaN
# 1  Andhra Pradesh Assam Bihar Chhattisgarh Delhi ...
# 2  List of cities in India by population List of ...  ,                        0                                                  1
# 0  vteGeography of India                                                NaN
# 1                Climate                           Climate Climatic regions
# 2                Geology  Fossil Parks Geology of India Indian Plate Stones
# 3              Landforms  Beaches Canals Desert Extreme points Glaciers ...
# 4                Regions  North India Northeast India East India South I...
# 5           Subdivisions  States and territories Autonomous administrati...
# 6            Environment  Biogeographic classification Ecoregions Fauna ...]

# %%
#selecting cities by population in to Dataframe(table)
df = pd.DataFrame(wiki_tab[0])

# %%
df.head()
# Out:
#       0          1                    2                 3  \
# 0  Rank       City  Population(2011)[3]  Population(2001)
# 1     1     Mumbai             12442373          11978450
# 2     2      Delhi             11007835           9879172
# 3     3  Bangalore              8436675           6537124
# 4     4  Hyderabad              6809970           3637483
#
#                           4
# 0  State or union territory
# 1               Maharashtra
# 2                     Delhi
# 3                 Karnataka
# 4                 Telangana

# %%
df.columns = ['rank', 'city', 'population_11', 'population_01', 'state']

# %%
df = df.drop([0])

# %%
#slicing top 50 cities
Top_city = df['city'][0:50].astype(str)
Top_city.head(50)
# Out:
# 1                  Mumbai
# 2                   Delhi
# 3               Bangalore
# 4               Hyderabad
# 5               Ahmedabad
# 6                 Chennai
# 7                 Kolkata
# 8                   Surat
# 9                    Pune
# 10                 Jaipur
# 11                Lucknow
# 12                 Kanpur
# 13                 Nagpur
# 14                 Indore
# 15                  Thane
# 16                 Bhopal
# 17    Visakhapatnam[a][5]
# 18       Pimpri-Chinchwad
# 19                  Patna
# 20               Vadodara
# 21              Ghaziabad
# 22               Ludhiana
# 23                   Agra
# 24                 Nashik
# 25              Faridabad
# 26                 Meerut
# 27                 Rajkot
# 28        Kalyan-Dombivli
# 29            Vasai-Virar
# 30               Varanasi
# 31               Srinagar
# 32             Aurangabad
# 33                Dhanbad
# 34               Amritsar
# 35            Navi Mumbai
# 36              Allahabad
# 37                 Howrah
# 38                 Ranchi
# 39                Gwalior
# 40               Jabalpur
# 41             Coimbatore
# 42             Vijayawada
# 43                Jodhpur
# 44                Madurai
# 45                 Raipur
# 46                Kota[6]
# 47             Chandigarh
# 48               Guwahati
# 49                Solapur
# 50          Hubli–Dharwad
# Name: city, dtype: object

# %%
# To clean the city names to match openweather api
def clean_text(txt):
 city = re.sub("(\-[A-Za-z0-9])|([^A-Za-z]+)", "", txt)
 return (city)

# %%
Top_cities = []
for x in Top_city:
    Top_cities.append(clean_text(x))

# %%
Top_cities[17] #check for -
# Out:
# 'Pimprihinchwad'

# %%
key = 'e853da8a71f32a9a4f71fafca2a8ca7a' #spare key

key2 = '1a3795c3407c047c44350035ff7f7c94'
base = 'http://api.openweathermap.org/data/2.5/forecast?'

# %%
URL = base + "appid=" + key + "&q="
url = base + "appid=" + key2 + "&q="

# %%
#data extraction from openweathermap api and looping for top 50 cities

forecast_dict = {}

def city_forecast(city):
    weather_data = req.get(url + city)
    weather_data = weather_data.json()
    if weather_data['cod'] == '200': #removes any empty data
      return weather_data

# %%
for city in Top_cities:
    forecast_dict[city] = city_forecast(city)

# %%
#Removing 'None' valued keys from the dict

forecast_dict1 = {k:v for k,v in forecast_dict.items() if v is not None}

# %%
pd.DataFrame(forecast_dict1) # visualizing in table to check any None values
# Out:
#                                                     Mumbai  \
# city     {'id': 1275339, 'name': 'Mumbai', 'coord': {'l...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 302.06, '...
# message                                             0.0069
#
#                                                      Delhi  \
# city     {'id': 1273294, 'name': 'Delhi', 'coord': {'la...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 309.02, '...
# message                                             0.0063
#
#                                                  Bangalore  \
# city     {'id': 1277333, 'name': 'Bangalore', 'coord': ...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 298.59, '...
# message                                             0.0067
#
#                                                  Hyderabad  \
# city     {'id': 1269843, 'name': 'Hyderabad', 'coord': ...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 301.72, '...
# message                                             0.0083
#
#                                                  Ahmedabad  \
# city     {'id': 1279233, 'name': 'Ahmedabad', 'coord': ...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 300.79, '...
# message                                             0.0099
#
#                                                    Chennai  \
# city     {'id': 1264527, 'name': 'Chennai', 'coord': {'...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 307.46, '...
# message                                              0.009
#
#                                                    Kolkata  \
# city     {'id': 1275004, 'name': 'Kolkata', 'coord': {'...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 302.24, '...
# message                                             0.0063
#
#                                                      Surat  \
# city     {'id': 1255364, 'name': 'Surat', 'coord': {'la...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 301.71, '...
# message                                             0.0071
#
#                                                       Pune  \
# city     {'id': 1259229, 'name': 'Pune', 'coord': {'lat...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 296.62, '...
# message                                             0.0065
#
#                                                     Jaipur  \
# city     {'id': 1269515, 'name': 'Jaipur', 'coord': {'l...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 306.58, '...
# message                                             0.0099
#
#                                ...                          \
# city                           ...
# cnt                            ...
# cod                            ...
# list                           ...
# message                        ...
#
#                                                   Jabalpur  \
# city     {'id': 1269633, 'name': 'Jabalpur', 'coord': {...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 305.56, '...
# message                                              0.009
#
#                                                 Coimbatore  \
# city     {'id': 1273865, 'name': 'Coimbatore', 'coord':...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 297.85, '...
# message                                             0.0085
#
#                                                 Vijayawada  \
# city     {'id': 1253184, 'name': 'Vijayawada', 'coord':...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 306.55, '...
# message                                             0.0068
#
#                                                    Jodhpur  \
# city     {'id': 1268865, 'name': 'Jodhpur', 'coord': {'...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 309.9, 't...
# message                                             0.0087
#
#                                                    Madurai  \
# city     {'id': 1264521, 'name': 'Madurai', 'coord': {'...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 301.48, '...
# message                                             0.0075
#
#                                                     Raipur  \
# city     {'id': 1258980, 'name': 'Raipur', 'coord': {'l...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 297.26, '...
# message                                             0.0084
#
#                                                       Kota  \
# city     {'id': 1266049, 'name': 'Kota', 'coord': {'lat...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 303.62, '...
# message                                             0.0081
#
#                                                 Chandigarh  \
# city     {'id': 1274746, 'name': 'Chandigarh', 'coord':...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 304.56, '...
# message                                             0.0095
#
#                                                   Guwahati  \
# city     {'id': 1271476, 'name': 'Guwahati', 'coord': {...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 305.98, '...
# message                                             0.0089
#
#                                                    Solapur
# city     {'id': 1256436, 'name': 'Solapur', 'coord': {'...
# cnt                                                     40
# cod                                                    200
# list     [{'dt': 1565244000, 'main': {'temp': 306.05, '...
# message                                             0.0066
#
# [5 rows x 44 columns]

# %%
from pandas.io.json import json_normalize  
from pprint import pprint

# %%
pprint(forecast_dict)
# Out:
# {'Agra': {'city': {'coord': {'lat': 27.1753, 'lon': 78.0098},
#                    'country': 'IN',
#                    'id': 1279259,
#                    'name': 'Agra',
#                    'population': 1430055,
#                    'timezone': 19800},
#           'cnt': 40,
#           'cod': '200',
#           'list': [{'clouds': {'all': 90},
#                     'dt': 1565244000,
#                     'dt_txt': '2019-08-08 06:00:00',
#                     'main': {'grnd_level': 975.36,
#                              'humidity': 44,
#                              'pressure': 994.88,
#                              'sea_level': 994.88,
#                              'temp': 312.53,
#                              'temp_kf': 3.01,
#                              'temp_max': 312.53,
#                              'temp_min': 309.527},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'overcast clouds',
#                                  'icon': '04d',
#                                  'id': 804,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 94.908, 'speed': 7.04}},
#                    {'clouds': {'all': 93},
#                     'dt': 1565254800,
#                     'dt_txt': '2019-08-08 09:00:00',
#                     'main': {'grnd_level': 973.53,
#                              'humidity': 44,
#                              'pressure': 992.31,
#                              'sea_level': 992.31,
#                              'temp': 311.97,
#                              'temp_kf': 2.26,
#                              'temp_max': 311.97,
#                              'temp_min': 309.711},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'overcast clouds',
#                                  'icon': '04d',
#                                  'id': 804,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 84.323, 'speed': 6.99}},
#                    {'clouds': {'all': 76},
#                     'dt': 1565265600,
#                     'dt_txt': '2019-08-08 12:00:00',
#                     'main': {'grnd_level': 972.22,
#                              'humidity': 46,
#                              'pressure': 990.69,
#                              'sea_level': 990.69,
#                              'temp': 309.95,
#                              'temp_kf': 1.5,
#                              'temp_max': 309.95,
#                              'temp_min': 308.443},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'broken clouds',
#                                  'icon': '04d',
#                                  'id': 803,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 88.495, 'speed': 6.28}},
#                    {'clouds': {'all': 0},
#                     'dt': 1565276400,
#                     'dt_txt': '2019-08-08 15:00:00',
#                     'main': {'grnd_level': 975,
#                              'humidity': 56,
#                              'pressure': 993.65,
#                              'sea_level': 993.65,
#                              'temp': 305.76,
#                              'temp_kf': 0.75,
#                              'temp_max': 305.76,
#                              'temp_min': 305.008},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'clear sky',
#                                  'icon': '01n',
#                                  'id': 800,
#                                  'main': 'Clear'}],
#                     'wind': {'deg': 99.391, 'speed': 3.3}},
#                    {'clouds': {'all': 2},
#                     'dt': 1565287200,
#                     'dt_txt': '2019-08-08 18:00:00',
#                     'main': {'grnd_level': 976.02,
#                              'humidity': 60,
#                              'pressure': 994.97,
#                              'sea_level': 994.97,
#                              'temp': 304.243,
#                              'temp_kf': 0,
#                              'temp_max': 304.243,
#                              'temp_min': 304.243},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'clear sky',
#                                  'icon': '01n',
#                                  'id': 800,
#                                  'main': 'Clear'}],
#                     'wind': {'deg': 76.564, 'speed': 4.86}},
#                    {'clouds': {'all': 9},
#                     'dt': 1565298000,
#                     'dt_txt': '2019-08-08 21:00:00',
#                     'main': {'grnd_level': 975.23,
#                              'humidity': 63,
#                              'pressure': 994.27,
#                              'sea_level': 994.27,
#                              'temp': 302.994,
#                              'temp_kf': 0,
#                              'temp_max': 302.994,
#                              'temp_min': 302.994},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'clear sky',
#                                  'icon': '01n',
#                                  'id': 800,
#                                  'main': 'Clear'}],
#                     'wind': {'deg': 92.237, 'speed': 6.1}},
#                    {'clouds': {'all': 17},
#                     'dt': 1565308800,
#                     'dt_txt': '2019-08-09 00:00:00',
#                     'main': {'grnd_level': 975.57,
#                              'humidity': 67,
#                              'pressure': 994.59,
#                              'sea_level': 994.59,
#                              'temp': 302.358,
#                              'temp_kf': 0,
#                              'temp_max': 302.358,
#                              'temp_min': 302.358},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'few clouds',
#                                  'icon': '02n',
#                                  'id': 801,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 77.884, 'speed': 6.07}},
#                    {'clouds': {'all': 38},
#                     'dt': 1565319600,
#                     'dt_txt': '2019-08-09 03:00:00',
#                     'main': {'grnd_level': 977.04,
#                              'humidity': 66,
#                              'pressure': 996,
#                              'sea_level': 996,
#                              'temp': 302.904,
#                              'temp_kf': 0,
#                              'temp_max': 302.904,
#                              'temp_min': 302.904},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'scattered clouds',
#                                  'icon': '03d',
#                                  'id': 802,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 86.408, 'speed': 7.63}},
#                    {'clouds': {'all': 58},
#                     'dt': 1565330400,
#                     'dt_txt': '2019-08-09 06:00:00',
#                     'main': {'grnd_level': 977.05,
#                              'humidity': 48,
#                              'pressure': 996.33,
#                              'sea_level': 996.33,
#                              'temp': 307.943,
#                              'temp_kf': 0,
#                              'temp_max': 307.943,
#                              'temp_min': 307.943},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'broken clouds',
#                                  'icon': '04d',
#                                  'id': 803,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 96.869, 'speed': 8.87}},
#                    {'clouds': {'all': 68},
#                     'dt': 1565341200,
#                     'dt_txt': '2019-08-09 09:00:00',
#                     'main': {'grnd_level': 974.37,
#                              'humidity': 45,
#                              'pressure': 993.34,
#                              'sea_level': 993.34,
#                              'temp': 308.616,
#                              'temp_kf': 0,
#                              'temp_max': 308.616,
#                              'temp_min': 308.616},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'broken clouds',
#                                  'icon': '04d',
#                                  'id': 803,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 99.347, 'speed': 7.94}},
#                    {'clouds': {'all': 84},
#                     'dt': 1565352000,
#                     'dt_txt': '2019-08-09 12:00:00',
#                     'main': {'grnd_level': 973.48,
#                              'humidity': 52,
#                              'pressure': 992.22,
#                              'sea_level': 992.22,
#                              'temp': 306.743,
#                              'temp_kf': 0,
#                              'temp_max': 306.743,
#                              'temp_min': 306.743},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'broken clouds',
#                                  'icon': '04d',
#                                  'id': 803,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 91.998, 'speed': 5.65}},
#                    {'clouds': {'all': 86},
#                     'dt': 1565362800,
#                     'dt_txt': '2019-08-09 15:00:00',
#                     'main': {'grnd_level': 975.4,
#                              'humidity': 56,
#                              'pressure': 994.23,
#                              'sea_level': 994.23,
#                              'temp': 305.035,
#                              'temp_kf': 0,
#                              'temp_max': 305.035,
#                              'temp_min': 305.035},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'overcast clouds',
#                                  'icon': '04n',
#                                  'id': 804,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 95.262, 'speed': 5.49}},
#                    {'clouds': {'all': 60},
#                     'dt': 1565373600,
#                     'dt_txt': '2019-08-09 18:00:00',
#                     'main': {'grnd_level': 976.53,
#                              'humidity': 61,
#                              'pressure': 995.6,
#                              'sea_level': 995.6,
#                              'temp': 303.566,
#                              'temp_kf': 0,
#                              'temp_max': 303.566,
#                              'temp_min': 303.566},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'broken clouds',
#                                  'icon': '04n',
#                                  'id': 803,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 105.512, 'speed': 5.64}},
#                    {'clouds': {'all': 0},
#                     'dt': 1565384400,
#                     'dt_txt': '2019-08-09 21:00:00',
#                     'main': {'grnd_level': 976.01,
#                              'humidity': 69,
#                              'pressure': 994.9,
#                              'sea_level': 994.9,
#                              'temp': 301.8,
#                              'temp_kf': 0,
#                              'temp_max': 301.8,
#                              'temp_min': 301.8},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'clear sky',
#                                  'icon': '01n',
#                                  'id': 800,
#                                  'main': 'Clear'}],
#                     'wind': {'deg': 119.493, 'speed': 5.96}},
#                    {'clouds': {'all': 1},
#                     'dt': 1565395200,
#                     'dt_txt': '2019-08-10 00:00:00',
#                     'main': {'grnd_level': 976.23,
#                              'humidity': 73,
#                              'pressure': 995.05,
#                              'sea_level': 995.05,
#                              'temp': 300.61,
#                              'temp_kf': 0,
#                              'temp_max': 300.61,
#                              'temp_min': 300.61},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'clear sky',
#                                  'icon': '01n',
#                                  'id': 800,
#                                  'main': 'Clear'}],
#                     'wind': {'deg': 116.432, 'speed': 5.58}},
#                    {'clouds': {'all': 0},
#                     'dt': 1565406000,
#                     'dt_txt': '2019-08-10 03:00:00',
#                     'main': {'grnd_level': 978.01,
#                              'humidity': 67,
#                              'pressure': 996.98,
#                              'sea_level': 996.98,
#                              'temp': 302.368,
#                              'temp_kf': 0,
#                              'temp_max': 302.368,
#                              'temp_min': 302.368},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'clear sky',
#                                  'icon': '01d',
#                                  'id': 800,
#                                  'main': 'Clear'}],
#                     'wind': {'deg': 123.672, 'speed': 6.99}},
#                    {'clouds': {'all': 11},
#                     'dt': 1565416800,
#                     'dt_txt': '2019-08-10 06:00:00',
#                     'main': {'grnd_level': 978.08,
#                              'humidity': 54,
#                              'pressure': 996.96,
#                              'sea_level': 996.96,
#                              'temp': 306.418,
#                              'temp_kf': 0,
#                              'temp_max': 306.418,
#                              'temp_min': 306.418},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'few clouds',
#                                  'icon': '02d',
#                                  'id': 801,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 135.983, 'speed': 6.64}},
#                    {'clouds': {'all': 42},
#                     'dt': 1565427600,
#                     'dt_txt': '2019-08-10 09:00:00',
#                     'main': {'grnd_level': 976.85,
#                              'humidity': 51,
#                              'pressure': 995.1,
#                              'sea_level': 995.1,
#                              'temp': 307.159,
#                              'temp_kf': 0,
#                              'temp_max': 307.159,
#                              'temp_min': 307.159},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'scattered clouds',
#                                  'icon': '03d',
#                                  'id': 802,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 166.155, 'speed': 6.12}},
#                    {'clouds': {'all': 52},
#                     'dt': 1565438400,
#                     'dt_txt': '2019-08-10 12:00:00',
#                     'main': {'grnd_level': 976.19,
#                              'humidity': 51,
#                              'pressure': 994.47,
#                              'sea_level': 994.47,
#                              'temp': 307,
#                              'temp_kf': 0,
#                              'temp_max': 307,
#                              'temp_min': 307},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'broken clouds',
#                                  'icon': '04d',
#                                  'id': 803,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 138.307, 'speed': 4.81}},
#                    {'clouds': {'all': 48},
#                     'dt': 1565449200,
#                     'dt_txt': '2019-08-10 15:00:00',
#                     'main': {'grnd_level': 978.07,
#                              'humidity': 59,
#                              'pressure': 996.46,
#                              'sea_level': 996.46,
#                              'temp': 304.441,
#                              'temp_kf': 0,
#                              'temp_max': 304.441,
#                              'temp_min': 304.441},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'scattered clouds',
#                                  'icon': '03n',
#                                  'id': 802,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 127.554, 'speed': 3.35}},
#                    {'clouds': {'all': 38},
#                     'dt': 1565460000,
#                     'dt_txt': '2019-08-10 18:00:00',
#                     'main': {'grnd_level': 979.26,
#                              'humidity': 67,
#                              'pressure': 997.93,
#                              'sea_level': 997.93,
#                              'temp': 303.073,
#                              'temp_kf': 0,
#                              'temp_max': 303.073,
#                              'temp_min': 303.073},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'scattered clouds',
#                                  'icon': '03n',
#                                  'id': 802,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 188.974, 'speed': 2.16}},
#                    {'clouds': {'all': 39},
#                     'dt': 1565470800,
#                     'dt_txt': '2019-08-10 21:00:00',
#                     'main': {'grnd_level': 978.86,
#                              'humidity': 70,
#                              'pressure': 997.56,
#                              'sea_level': 997.56,
#                              'temp': 301.898,
#                              'temp_kf': 0,
#                              'temp_max': 301.898,
#                              'temp_min': 301.898},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'scattered clouds',
#                                  'icon': '03n',
#                                  'id': 802,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 191.319, 'speed': 2.6}},
#                    {'clouds': {'all': 20},
#                     'dt': 1565481600,
#                     'dt_txt': '2019-08-11 00:00:00',
#                     'main': {'grnd_level': 979.18,
#                              'humidity': 75,
#                              'pressure': 998.06,
#                              'sea_level': 998.06,
#                              'temp': 300.8,
#                              'temp_kf': 0,
#                              'temp_max': 300.8,
#                              'temp_min': 300.8},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'few clouds',
#                                  'icon': '02n',
#                                  'id': 801,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 194.743, 'speed': 2.87}},
#                    {'clouds': {'all': 1},
#                     'dt': 1565492400,
#                     'dt_txt': '2019-08-11 03:00:00',
#                     'main': {'grnd_level': 980.14,
#                              'humidity': 66,
#                              'pressure': 999.12,
#                              'sea_level': 999.12,
#                              'temp': 302.906,
#                              'temp_kf': 0,
#                              'temp_max': 302.906,
#                              'temp_min': 302.906},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'clear sky',
#                                  'icon': '01d',
#                                  'id': 800,
#                                  'main': 'Clear'}],
#                     'wind': {'deg': 200.2, 'speed': 3.07}},
#                    {'clouds': {'all': 50},
#                     'dt': 1565503200,
#                     'dt_txt': '2019-08-11 06:00:00',
#                     'main': {'grnd_level': 979.74,
#                              'humidity': 51,
#                              'pressure': 998.62,
#                              'sea_level': 998.62,
#                              'temp': 306.924,
#                              'temp_kf': 0,
#                              'temp_max': 306.924,
#                              'temp_min': 306.924},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'scattered clouds',
#                                  'icon': '03d',
#                                  'id': 802,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 189.007, 'speed': 3.25}},
#                    {'clouds': {'all': 98},
#                     'dt': 1565514000,
#                     'dt_txt': '2019-08-11 09:00:00',
#                     'main': {'grnd_level': 977.31,
#                              'humidity': 50,
#                              'pressure': 995.87,
#                              'sea_level': 995.87,
#                              'temp': 308.3,
#                              'temp_kf': 0,
#                              'temp_max': 308.3,
#                              'temp_min': 308.3},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'overcast clouds',
#                                  'icon': '04d',
#                                  'id': 804,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 219.742, 'speed': 3.78}},
#                    {'clouds': {'all': 99},
#                     'dt': 1565524800,
#                     'dt_txt': '2019-08-11 12:00:00',
#                     'main': {'grnd_level': 976.64,
#                              'humidity': 56,
#                              'pressure': 995.12,
#                              'sea_level': 995.12,
#                              'temp': 307,
#                              'temp_kf': 0,
#                              'temp_max': 307,
#                              'temp_min': 307},
#                     'rain': {'3h': 0.188},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'light rain',
#                                  'icon': '10d',
#                                  'id': 500,
#                                  'main': 'Rain'}],
#                     'wind': {'deg': 241.193, 'speed': 4.5}},
#                    {'clouds': {'all': 7},
#                     'dt': 1565535600,
#                     'dt_txt': '2019-08-11 15:00:00',
#                     'main': {'grnd_level': 978.34,
#                              'humidity': 62,
#                              'pressure': 997.05,
#                              'sea_level': 997.05,
#                              'temp': 304.771,
#                              'temp_kf': 0,
#                              'temp_max': 304.771,
#                              'temp_min': 304.771},
#                     'rain': {'3h': 0.125},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'light rain',
#                                  'icon': '10n',
#                                  'id': 500,
#                                  'main': 'Rain'}],
#                     'wind': {'deg': 230.156, 'speed': 3.65}},
#                    {'clouds': {'all': 3},
#                     'dt': 1565546400,
#                     'dt_txt': '2019-08-11 18:00:00',
#                     'main': {'grnd_level': 979.82,
#                              'humidity': 64,
#                              'pressure': 998.63,
#                              'sea_level': 998.63,
#                              'temp': 303.512,
#                              'temp_kf': 0,
#                              'temp_max': 303.512,
#                              'temp_min': 303.512},
#                     'rain': {},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'clear sky',
#                                  'icon': '01n',
#                                  'id': 800,
#                                  'main': 'Clear'}],
#                     'wind': {'deg': 247.702, 'speed': 3.84}},
#                    {'clouds': {'all': 8},
#                     'dt': 1565557200,
#                     'dt_txt': '2019-08-11 21:00:00',
#                     'main': {'grnd_level': 978.74,
#                              'humidity': 69,
#                              'pressure': 997.67,
#                              'sea_level': 997.67,
#                              'temp': 302.549,
#                              'temp_kf': 0,
#                              'temp_max': 302.549,
#                              'temp_min': 302.549},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'clear sky',
#                                  'icon': '01n',
#                                  'id': 800,
#                                  'main': 'Clear'}],
#                     'wind': {'deg': 227.376, 'speed': 3.16}},
#                    {'clouds': {'all': 31},
#                     'dt': 1565568000,
#                     'dt_txt': '2019-08-12 00:00:00',
#                     'main': {'grnd_level': 979.25,
#                              'humidity': 76,
#                              'pressure': 998.33,
#                              'sea_level': 998.33,
#                              'temp': 301.78,
#                              'temp_kf': 0,
#                              'temp_max': 301.78,
#                              'temp_min': 301.78},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'scattered clouds',
#                                  'icon': '03n',
#                                  'id': 802,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 240.063, 'speed': 3.88}},
#                    {'clouds': {'all': 78},
#                     'dt': 1565578800,
#                     'dt_txt': '2019-08-12 03:00:00',
#                     'main': {'grnd_level': 980.37,
#                              'humidity': 62,
#                              'pressure': 999.59,
#                              'sea_level': 999.59,
#                              'temp': 305.1,
#                              'temp_kf': 0,
#                              'temp_max': 305.1,
#                              'temp_min': 305.1},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'broken clouds',
#                                  'icon': '04d',
#                                  'id': 803,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 275.166, 'speed': 5.31}},
#                    {'clouds': {'all': 83},
#                     'dt': 1565589600,
#                     'dt_txt': '2019-08-12 06:00:00',
#                     'main': {'grnd_level': 979.78,
#                              'humidity': 47,
#                              'pressure': 999.04,
#                              'sea_level': 999.04,
#                              'temp': 309.54,
#                              'temp_kf': 0,
#                              'temp_max': 309.54,
#                              'temp_min': 309.54},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'broken clouds',
#                                  'icon': '04d',
#                                  'id': 803,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 281.276, 'speed': 4.63}},
#                    {'clouds': {'all': 100},
#                     'dt': 1565600400,
#                     'dt_txt': '2019-08-12 09:00:00',
#                     'main': {'grnd_level': 977.18,
#                              'humidity': 49,
#                              'pressure': 995.99,
#                              'sea_level': 995.99,
#                              'temp': 309.028,
#                              'temp_kf': 0,
#                              'temp_max': 309.028,
#                              'temp_min': 309.028},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'overcast clouds',
#                                  'icon': '04d',
#                                  'id': 804,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 258.937, 'speed': 5.23}},
#                    {'clouds': {'all': 98},
#                     'dt': 1565611200,
#                     'dt_txt': '2019-08-12 12:00:00',
#                     'main': {'grnd_level': 976.68,
#                              'humidity': 53,
#                              'pressure': 995.13,
#                              'sea_level': 995.13,
#                              'temp': 307.834,
#                              'temp_kf': 0,
#                              'temp_max': 307.834,
#                              'temp_min': 307.834},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'overcast clouds',
#                                  'icon': '04d',
#                                  'id': 804,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 279.491, 'speed': 6.93}},
#                    {'clouds': {'all': 98},
#                     'dt': 1565622000,
#                     'dt_txt': '2019-08-12 15:00:00',
#                     'main': {'grnd_level': 977.42,
#                              'humidity': 62,
#                              'pressure': 996.09,
#                              'sea_level': 996.09,
#                              'temp': 305.234,
#                              'temp_kf': 0,
#                              'temp_max': 305.234,
#                              'temp_min': 305.234},
#                     'rain': {'3h': 0.375},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'light rain',
#                                  'icon': '10n',
#                                  'id': 500,
#                                  'main': 'Rain'}],
#                     'wind': {'deg': 220.193, 'speed': 3.54}},
#                    {'clouds': {'all': 99},
#                     'dt': 1565632800,
#                     'dt_txt': '2019-08-12 18:00:00',
#                     'main': {'grnd_level': 978.38,
#                              'humidity': 61,
#                              'pressure': 997.08,
#                              'sea_level': 997.08,
#                              'temp': 305.2,
#                              'temp_kf': 0,
#                              'temp_max': 305.2,
#                              'temp_min': 305.2},
#                     'rain': {},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'overcast clouds',
#                                  'icon': '04n',
#                                  'id': 804,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 253.179, 'speed': 4.06}},
#                    {'clouds': {'all': 100},
#                     'dt': 1565643600,
#                     'dt_txt': '2019-08-12 21:00:00',
#                     'main': {'grnd_level': 977.07,
#                              'humidity': 63,
#                              'pressure': 995.88,
#                              'sea_level': 995.88,
#                              'temp': 304.278,
#                              'temp_kf': 0,
#                              'temp_max': 304.278,
#                              'temp_min': 304.278},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'overcast clouds',
#                                  'icon': '04n',
#                                  'id': 804,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 260.952, 'speed': 4.78}},
#                    {'clouds': {'all': 100},
#                     'dt': 1565654400,
#                     'dt_txt': '2019-08-13 00:00:00',
#                     'main': {'grnd_level': 977.49,
#                              'humidity': 63,
#                              'pressure': 996.39,
#                              'sea_level': 996.39,
#                              'temp': 303.6,
#                              'temp_kf': 0,
#                              'temp_max': 303.6,
#                              'temp_min': 303.6},
#                     'sys': {'pod': 'n'},
#                     'weather': [{'description': 'overcast clouds',
#                                  'icon': '04n',
#                                  'id': 804,
#                                  'main': 'Clouds'}],
#                     'wind': {'deg': 264.525, 'speed': 4.73}},
#                    {'clouds': {'all': 100},
#                     'dt': 1565665200,
#                     'dt_txt': '2019-08-13 03:00:00',
#                     'main': {'grnd_level': 978.5,
#                              'humidity': 62,
#                              'pressure': 997.78,
#                              'sea_level': 997.78,
#                              'temp': 304.124,
#                              'temp_kf': 0,
#                              'temp_max': 304.124,
#                              'temp_min': 304.124},
#                     'rain': {'3h': 0.375},
#                     'sys': {'pod': 'd'},
#                     'weather': [{'description': 'light rain',
#                                  'icon': '10d',
#                                  'id': 500,
#                                  'main': 'Rain'}],
#                     'wind': {'deg': 266.459, 'speed': 5.81}}],
#           'message': 0.0066},
#  'Ahmedabad': {'city': {'coord': {'lat': 23.0216, 'lon': 72.5797},
#                         'country': 'IN',
#                         'id': 1279233,
#                         'name': 'Ahmedabad',
#                         'population': 3719710,
#                         'timezone': 19800},
#                'cnt': 40,
#                'cod': '200',
#                'list': [{'clouds': {'all': 100},
#                          'dt': 1565244000,
#                          'dt_txt': '2019-08-08 06:00:00',
#                          'main': {'grnd_level': 992.69,
#                                   'humidity': 91,
#                                   'pressure': 997.93,
#                                   'sea_level': 997.93,
#                                   'temp': 300.79,
#                                   'temp_kf': 1.67,
#                                   'temp_max': 300.79,
#                                   'temp_min': 299.127},
#                          'rain': {'3h': 16.437},
#                          'sys': {'pod': 'd'},
#                          'weather': [{'description': 'heavy intensity rain',
#                                       'icon': '10d',
#                                       'id': 502,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 264.468, 'speed': 4.48}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565254800,
#                          'dt_txt': '2019-08-08 09:00:00',
#                          'main': {'grnd_level': 991.25,
#                                   'humidity': 82,
#                                   'pressure': 996.2,
#                                   'sea_level': 996.2,
#                                   'temp': 301.76,
#                                   'temp_kf': 1.25,
#                                   'temp_max': 301.76,
#                                   'temp_min': 300.511},
#                          'rain': {'3h': 3.375},
#                          'sys': {'pod': 'd'},
#                          'weather': [{'description': 'moderate rain',
#                                       'icon': '10d',
#                                       'id': 501,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 249.056, 'speed': 5.62}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565265600,
#                          'dt_txt': '2019-08-08 12:00:00',
#                          'main': {'grnd_level': 989.5,
#                                   'humidity': 71,
#                                   'pressure': 994.87,
#                                   'sea_level': 994.87,
#                                   'temp': 303.28,
#                                   'temp_kf': 0.83,
#                                   'temp_max': 303.28,
#                                   'temp_min': 302.443},
#                          'rain': {'3h': 0.563},
#                          'sys': {'pod': 'd'},
#                          'weather': [{'description': 'light rain',
#                                       'icon': '10d',
#                                       'id': 500,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 265.746, 'speed': 5.59}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565276400,
#                          'dt_txt': '2019-08-08 15:00:00',
#                          'main': {'grnd_level': 991.13,
#                                   'humidity': 81,
#                                   'pressure': 996.32,
#                                   'sea_level': 996.32,
#                                   'temp': 301.32,
#                                   'temp_kf': 0.42,
#                                   'temp_max': 301.32,
#                                   'temp_min': 300.908},
#                          'rain': {'3h': 3.625},
#                          'sys': {'pod': 'n'},
#                          'weather': [{'description': 'moderate rain',
#                                       'icon': '10n',
#                                       'id': 501,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 279.639, 'speed': 2.93}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565287200,
#                          'dt_txt': '2019-08-08 18:00:00',
#                          'main': {'grnd_level': 991.41,
#                                   'humidity': 86,
#                                   'pressure': 997.03,
#                                   'sea_level': 997.03,
#                                   'temp': 299.643,
#                                   'temp_kf': 0,
#                                   'temp_max': 299.643,
#                                   'temp_min': 299.643},
#                          'rain': {'3h': 3.125},
#                          'sys': {'pod': 'n'},
#                          'weather': [{'description': 'moderate rain',
#                                       'icon': '10n',
#                                       'id': 501,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 236.821, 'speed': 3.73}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565298000,
#                          'dt_txt': '2019-08-08 21:00:00',
#                          'main': {'grnd_level': 990.05,
#                                   'humidity': 88,
#                                   'pressure': 995.17,
#                                   'sea_level': 995.17,
#                                   'temp': 299.954,
#                                   'temp_kf': 0,
#                                   'temp_max': 299.954,
#                                   'temp_min': 299.954},
#                          'rain': {'3h': 2.5},
#                          'sys': {'pod': 'n'},
#                          'weather': [{'description': 'light rain',
#                                       'icon': '10n',
#                                       'id': 500,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 272.201, 'speed': 5.26}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565308800,
#                          'dt_txt': '2019-08-09 00:00:00',
#                          'main': {'grnd_level': 989.25,
#                                   'humidity': 89,
#                                   'pressure': 994.12,
#                                   'sea_level': 994.12,
#                                   'temp': 299.738,
#                                   'temp_kf': 0,
#                                   'temp_max': 299.738,
#                                   'temp_min': 299.738},
#                          'rain': {'3h': 4.625},
#                          'sys': {'pod': 'n'},
#                          'weather': [{'description': 'moderate rain',
#                                       'icon': '10n',
#                                       'id': 501,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 293.32, 'speed': 6.9}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565319600,
#                          'dt_txt': '2019-08-09 03:00:00',
#                          'main': {'grnd_level': 989.87,
#                                   'humidity': 92,
#                                   'pressure': 995.04,
#                                   'sea_level': 995.04,
#                                   'temp': 299.414,
#                                   'temp_kf': 0,
#                                   'temp_max': 299.414,
#                                   'temp_min': 299.414},
#                          'rain': {'3h': 14.562},
#                          'sys': {'pod': 'd'},
#                          'weather': [{'description': 'heavy intensity rain',
#                                       'icon': '10d',
#                                       'id': 502,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 292.043, 'speed': 7.83}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565330400,
#                          'dt_txt': '2019-08-09 06:00:00',
#                          'main': {'grnd_level': 990.89,
#                                   'humidity': 88,
#                                   'pressure': 995.21,
#                                   'sea_level': 995.21,
#                                   'temp': 299.943,
#                                   'temp_kf': 0,
#                                   'temp_max': 299.943,
#                                   'temp_min': 299.943},
#                          'rain': {'3h': 8.938},
#                          'sys': {'pod': 'd'},
#                          'weather': [{'description': 'moderate rain',
#                                       'icon': '10d',
#                                       'id': 501,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 292.967, 'speed': 5.3}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565341200,
#                          'dt_txt': '2019-08-09 09:00:00',
#                          'main': {'grnd_level': 989.01,
#                                   'humidity': 83,
#                                   'pressure': 993.87,
#                                   'sea_level': 993.87,
#                                   'temp': 301.016,
#                                   'temp_kf': 0,
#                                   'temp_max': 301.016,
#                                   'temp_min': 301.016},
#                          'rain': {'3h': 3.188},
#                          'sys': {'pod': 'd'},
#                          'weather': [{'description': 'moderate rain',
#                                       'icon': '10d',
#                                       'id': 501,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 284.092, 'speed': 8.67}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565352000,
#                          'dt_txt': '2019-08-09 12:00:00',
#                          'main': {'grnd_level': 987.21,
#                                   'humidity': 91,
#                                   'pressure': 992.04,
#                                   'sea_level': 992.04,
#                                   'temp': 300.043,
#                                   'temp_kf': 0,
#                                   'temp_max': 300.043,
#                                   'temp_min': 300.043},
#                          'rain': {'3h': 15.812},
#                          'sys': {'pod': 'd'},
#                          'weather': [{'description': 'heavy intensity rain',
#                                       'icon': '10d',
#                                       'id': 502,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 315.447, 'speed': 4.62}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565362800,
#                          'dt_txt': '2019-08-09 15:00:00',
#                          'main': {'grnd_level': 987.91,
#                                   'humidity': 85,
#                                   'pressure': 993.12,
#                                   'sea_level': 993.12,
#                                   'temp': 301.035,
#                                   'temp_kf': 0,
#                                   'temp_max': 301.035,
#                                   'temp_min': 301.035},
#                          'rain': {'3h': 13.062},
#                          'sys': {'pod': 'n'},
#                          'weather': [{'description': 'heavy intensity rain',
#                                       'icon': '10n',
#                                       'id': 502,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 303.274, 'speed': 8.22}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565373600,
#                          'dt_txt': '2019-08-09 18:00:00',
#                          'main': {'grnd_level': 988.57,
#                                   'humidity': 86,
#                                   'pressure': 993.94,
#                                   'sea_level': 993.94,
#                                   'temp': 300.666,
#                                   'temp_kf': 0,
#                                   'temp_max': 300.666,
#                                   'temp_min': 300.666},
#                          'rain': {'3h': 8.938},
#                          'sys': {'pod': 'n'},
#                          'weather': [{'description': 'moderate rain',
#                                       'icon': '10n',
#                                       'id': 501,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 298.273, 'speed': 8.24}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565384400,
#                          'dt_txt': '2019-08-09 21:00:00',
#                          'main': {'grnd_level': 986.57,
#                                   'humidity': 86,
#                                   'pressure': 992,
#                                   'sea_level': 992,
#                                   'temp': 300.7,
#                                   'temp_kf': 0,
#                                   'temp_max': 300.7,
#                                   'temp_min': 300.7},
#                          'rain': {'3h': 10},
#                          'sys': {'pod': 'n'},
#                          'weather': [{'description': 'moderate rain',
#                                       'icon': '10n',
#                                       'id': 501,
#                                       'main': 'Rain'}],
#                          'wind': {'deg': 302.288, 'speed': 2.69}},
#                         {'clouds': {'all': 100},
#                          'dt': 1565395200,
#                          'dt_txt': '2019-08-10 00:00:00',
#                          'main': {'grnd_level': 986.33,
#                                   'humidity': 94,
#                                   'pressure': 991.23,
#                                   'sea_level': 991.23,
#                                   'temp': 298.75,
# ...
#                           'dt': 1565492400,
#                           'dt_txt': '2019-08-11 03:00:00',
#                           'main': {'grnd_level': 1001.22,
#                                    'humidity': 69,
#                                    'pressure': 1005.38,
#                                    'sea_level': 1005.38,
#                                    'temp': 302.016,
#                                    'temp_kf': 0,
#                                    'temp_max': 302.016,
#                                    'temp_min': 302.016},
#                           'sys': {'pod': 'd'},
#                           'weather': [{'description': 'broken clouds',
#                                        'icon': '04d',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 280.33, 'speed': 5.79}},
#                          {'clouds': {'all': 83},
#                           'dt': 1565503200,
#                           'dt_txt': '2019-08-11 06:00:00',
#                           'main': {'grnd_level': 1000.45,
#                                    'humidity': 57,
#                                    'pressure': 1004.68,
#                                    'sea_level': 1004.68,
#                                    'temp': 305.424,
#                                    'temp_kf': 0,
#                                    'temp_max': 305.424,
#                                    'temp_min': 305.424},
#                           'sys': {'pod': 'd'},
#                           'weather': [{'description': 'broken clouds',
#                                        'icon': '04d',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 289.427, 'speed': 5.61}},
#                          {'clouds': {'all': 99},
#                           'dt': 1565514000,
#                           'dt_txt': '2019-08-11 09:00:00',
#                           'main': {'grnd_level': 997.15,
#                                    'humidity': 50,
#                                    'pressure': 1001.48,
#                                    'sea_level': 1001.48,
#                                    'temp': 307.5,
#                                    'temp_kf': 0,
#                                    'temp_max': 307.5,
#                                    'temp_min': 307.5},
#                           'sys': {'pod': 'd'},
#                           'weather': [{'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 301.871, 'speed': 5.46}},
#                          {'clouds': {'all': 99},
#                           'dt': 1565524800,
#                           'dt_txt': '2019-08-11 12:00:00',
#                           'main': {'grnd_level': 996.85,
#                                    'humidity': 62,
#                                    'pressure': 1001.22,
#                                    'sea_level': 1001.22,
#                                    'temp': 305.6,
#                                    'temp_kf': 0,
#                                    'temp_max': 305.6,
#                                    'temp_min': 305.6},
#                           'sys': {'pod': 'd'},
#                           'weather': [{'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 331.835, 'speed': 2.92}},
#                          {'clouds': {'all': 100},
#                           'dt': 1565535600,
#                           'dt_txt': '2019-08-11 15:00:00',
#                           'main': {'grnd_level': 999.45,
#                                    'humidity': 71,
#                                    'pressure': 1003.66,
#                                    'sea_level': 1003.66,
#                                    'temp': 302.571,
#                                    'temp_kf': 0,
#                                    'temp_max': 302.571,
#                                    'temp_min': 302.571},
#                           'rain': {'3h': 0.125},
#                           'sys': {'pod': 'n'},
#                           'weather': [{'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                           'wind': {'deg': 333.65, 'speed': 1.79}},
#                          {'clouds': {'all': 95},
#                           'dt': 1565546400,
#                           'dt_txt': '2019-08-11 18:00:00',
#                           'main': {'grnd_level': 999.93,
#                                    'humidity': 73,
#                                    'pressure': 1004.27,
#                                    'sea_level': 1004.27,
#                                    'temp': 301.912,
#                                    'temp_kf': 0,
#                                    'temp_max': 301.912,
#                                    'temp_min': 301.912},
#                           'rain': {'3h': 0.125},
#                           'sys': {'pod': 'n'},
#                           'weather': [{'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                           'wind': {'deg': 275.096, 'speed': 1.75}},
#                          {'clouds': {'all': 80},
#                           'dt': 1565557200,
#                           'dt_txt': '2019-08-11 21:00:00',
#                           'main': {'grnd_level': 998.85,
#                                    'humidity': 73,
#                                    'pressure': 1003,
#                                    'sea_level': 1003,
#                                    'temp': 300.849,
#                                    'temp_kf': 0,
#                                    'temp_max': 300.849,
#                                    'temp_min': 300.849},
#                           'sys': {'pod': 'n'},
#                           'weather': [{'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 286.788, 'speed': 3.33}},
#                          {'clouds': {'all': 84},
#                           'dt': 1565568000,
#                           'dt_txt': '2019-08-12 00:00:00',
#                           'main': {'grnd_level': 999.86,
#                                    'humidity': 73,
#                                    'pressure': 1003.89,
#                                    'sea_level': 1003.89,
#                                    'temp': 299.98,
#                                    'temp_kf': 0,
#                                    'temp_max': 299.98,
#                                    'temp_min': 299.98},
#                           'sys': {'pod': 'n'},
#                           'weather': [{'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 284.981, 'speed': 4.12}},
#                          {'clouds': {'all': 86},
#                           'dt': 1565578800,
#                           'dt_txt': '2019-08-12 03:00:00',
#                           'main': {'grnd_level': 1001.62,
#                                    'humidity': 67,
#                                    'pressure': 1005.68,
#                                    'sea_level': 1005.68,
#                                    'temp': 302.2,
#                                    'temp_kf': 0,
#                                    'temp_max': 302.2,
#                                    'temp_min': 302.2},
#                           'sys': {'pod': 'd'},
#                           'weather': [{'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 296.033, 'speed': 6.79}},
#                          {'clouds': {'all': 79},
#                           'dt': 1565589600,
#                           'dt_txt': '2019-08-12 06:00:00',
#                           'main': {'grnd_level': 1001.04,
#                                    'humidity': 56,
#                                    'pressure': 1005.24,
#                                    'sea_level': 1005.24,
#                                    'temp': 305.64,
#                                    'temp_kf': 0,
#                                    'temp_max': 305.64,
#                                    'temp_min': 305.64},
#                           'sys': {'pod': 'd'},
#                           'weather': [{'description': 'broken clouds',
#                                        'icon': '04d',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 308.673, 'speed': 6.31}},
#                          {'clouds': {'all': 98},
#                           'dt': 1565600400,
#                           'dt_txt': '2019-08-12 09:00:00',
#                           'main': {'grnd_level': 998.09,
#                                    'humidity': 53,
#                                    'pressure': 1002.24,
#                                    'sea_level': 1002.24,
#                                    'temp': 306.728,
#                                    'temp_kf': 0,
#                                    'temp_max': 306.728,
#                                    'temp_min': 306.728},
#                           'sys': {'pod': 'd'},
#                           'weather': [{'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 320.517, 'speed': 5.23}},
#                          {'clouds': {'all': 99},
#                           'dt': 1565611200,
#                           'dt_txt': '2019-08-12 12:00:00',
#                           'main': {'grnd_level': 997.46,
#                                    'humidity': 62,
#                                    'pressure': 1001.71,
#                                    'sea_level': 1001.71,
#                                    'temp': 305.434,
#                                    'temp_kf': 0,
#                                    'temp_max': 305.434,
#                                    'temp_min': 305.434},
#                           'sys': {'pod': 'd'},
#                           'weather': [{'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 348.94, 'speed': 3.06}},
#                          {'clouds': {'all': 100},
#                           'dt': 1565622000,
#                           'dt_txt': '2019-08-12 15:00:00',
#                           'main': {'grnd_level': 999.58,
#                                    'humidity': 70,
#                                    'pressure': 1003.91,
#                                    'sea_level': 1003.91,
#                                    'temp': 302.734,
#                                    'temp_kf': 0,
#                                    'temp_max': 302.734,
#                                    'temp_min': 302.734},
#                           'sys': {'pod': 'n'},
#                           'weather': [{'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 308.646, 'speed': 1.94}},
#                          {'clouds': {'all': 100},
#                           'dt': 1565632800,
#                           'dt_txt': '2019-08-12 18:00:00',
#                           'main': {'grnd_level': 1000.05,
#                                    'humidity': 73,
#                                    'pressure': 1004.16,
#                                    'sea_level': 1004.16,
#                                    'temp': 301.7,
#                                    'temp_kf': 0,
#                                    'temp_max': 301.7,
#                                    'temp_min': 301.7},
#                           'sys': {'pod': 'n'},
#                           'weather': [{'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 287.68, 'speed': 2.35}},
#                          {'clouds': {'all': 100},
#                           'dt': 1565643600,
#                           'dt_txt': '2019-08-12 21:00:00',
#                           'main': {'grnd_level': 998.27,
#                                    'humidity': 76,
#                                    'pressure': 1002.42,
#                                    'sea_level': 1002.42,
#                                    'temp': 300.978,
#                                    'temp_kf': 0,
#                                    'temp_max': 300.978,
#                                    'temp_min': 300.978},
#                           'sys': {'pod': 'n'},
#                           'weather': [{'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 291.217, 'speed': 2.68}},
#                          {'clouds': {'all': 100},
#                           'dt': 1565654400,
#                           'dt_txt': '2019-08-13 00:00:00',
#                           'main': {'grnd_level': 999.05,
#                                    'humidity': 75,
#                                    'pressure': 1003.24,
#                                    'sea_level': 1003.24,
#                                    'temp': 300.7,
#                                    'temp_kf': 0,
#                                    'temp_max': 300.7,
#                                    'temp_min': 300.7},
#                           'sys': {'pod': 'n'},
#                           'weather': [{'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 282.515, 'speed': 3.92}},
#                          {'clouds': {'all': 100},
#                           'dt': 1565665200,
#                           'dt_txt': '2019-08-13 03:00:00',
#                           'main': {'grnd_level': 1001.26,
#                                    'humidity': 67,
#                                    'pressure': 1005.26,
#                                    'sea_level': 1005.26,
#                                    'temp': 303.024,
#                                    'temp_kf': 0,
#                                    'temp_max': 303.024,
#                                    'temp_min': 303.024},
#                           'sys': {'pod': 'd'},
#                           'weather': [{'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                           'wind': {'deg': 303.669, 'speed': 6.95}}],
#                 'message': 0.0068},
#  'Visakhapatnama': None}

# %%
#unpack list by parsing through json file
forecast_data = {}
for city in forecast_dict1.keys():
    forecast_data[city] = list(forecast_dict1[city]['list'])    
forecast_data
# Out:
# {'Mumbai': [{'dt': 1565244000,
#    'main': {'temp': 302.06,
#     'temp_min': 301.527,
#     'temp_max': 302.06,
#     'pressure': 1001.23,
#     'sea_level': 1001.23,
#     'grnd_level': 1001.17,
#     'humidity': 83,
#     'temp_kf': 0.53},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 11.61, 'deg': 256.134},
#    'rain': {'3h': 0.812},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-08 06:00:00'},
#   {'dt': 1565254800,
#    'main': {'temp': 301.91,
#     'temp_min': 301.511,
#     'temp_max': 301.91,
#     'pressure': 999.63,
#     'sea_level': 999.63,
#     'grnd_level': 999.41,
#     'humidity': 82,
#     'temp_kf': 0.4},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 11.51, 'deg': 253.805},
#    'rain': {'3h': 0.625},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-08 09:00:00'},
#   {'dt': 1565265600,
#    'main': {'temp': 301.71,
#     'temp_min': 301.443,
#     'temp_max': 301.71,
#     'pressure': 998.36,
#     'sea_level': 998.36,
#     'grnd_level': 998.17,
#     'humidity': 82,
#     'temp_kf': 0.26},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 11.73, 'deg': 255.915},
#    'rain': {'3h': 0.75},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-08 12:00:00'},
#   {'dt': 1565276400,
#    'main': {'temp': 301.64,
#     'temp_min': 301.508,
#     'temp_max': 301.64,
#     'pressure': 1000.24,
#     'sea_level': 1000.24,
#     'grnd_level': 1000.09,
#     'humidity': 82,
#     'temp_kf': 0.13},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 12.07, 'deg': 256.545},
#    'rain': {'3h': 1.062},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-08 15:00:00'},
#   {'dt': 1565287200,
#    'main': {'temp': 301.343,
#     'temp_min': 301.343,
#     'temp_max': 301.343,
#     'pressure': 1000.38,
#     'sea_level': 1000.38,
#     'grnd_level': 1000.29,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 13.27, 'deg': 256.006},
#    'rain': {'3h': 0.876},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-08 18:00:00'},
#   {'dt': 1565298000,
#    'main': {'temp': 301.344,
#     'temp_min': 301.344,
#     'temp_max': 301.344,
#     'pressure': 998.76,
#     'sea_level': 998.76,
#     'grnd_level': 998.59,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 13.1, 'deg': 254.198},
#    'rain': {'3h': 0.438},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-08 21:00:00'},
#   {'dt': 1565308800,
#    'main': {'temp': 301.378,
#     'temp_min': 301.378,
#     'temp_max': 301.378,
#     'pressure': 998.7,
#     'sea_level': 998.7,
#     'grnd_level': 998.48,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 12.38, 'deg': 254.36},
#    'rain': {'3h': 1},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 00:00:00'},
#   {'dt': 1565319600,
#    'main': {'temp': 301.424,
#     'temp_min': 301.424,
#     'temp_max': 301.424,
#     'pressure': 1000.43,
#     'sea_level': 1000.43,
#     'grnd_level': 1000.06,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 13.17, 'deg': 252.941},
#    'rain': {'3h': 3.375},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 03:00:00'},
#   {'dt': 1565330400,
#    'main': {'temp': 300.543,
#     'temp_min': 300.543,
#     'temp_max': 300.543,
#     'pressure': 1001.38,
#     'sea_level': 1001.38,
#     'grnd_level': 1001.27,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 14.57, 'deg': 258.996},
#    'rain': {'3h': 5.25},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 06:00:00'},
#   {'dt': 1565341200,
#    'main': {'temp': 300.416,
#     'temp_min': 300.416,
#     'temp_max': 300.416,
#     'pressure': 1000.82,
#     'sea_level': 1000.82,
#     'grnd_level': 1000.55,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 14.89, 'deg': 248.951},
#    'rain': {'3h': 9.312},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 09:00:00'},
#   {'dt': 1565352000,
#    'main': {'temp': 301.243,
#     'temp_min': 301.243,
#     'temp_max': 301.243,
#     'pressure': 998.93,
#     'sea_level': 998.93,
#     'grnd_level': 998.7,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 14.36, 'deg': 248.828},
#    'rain': {'3h': 4.376},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 12:00:00'},
#   {'dt': 1565362800,
#    'main': {'temp': 301.435,
#     'temp_min': 301.435,
#     'temp_max': 301.435,
#     'pressure': 1000.03,
#     'sea_level': 1000.03,
#     'grnd_level': 999.75,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 14.43, 'deg': 249.291},
#    'rain': {'3h': 2.688},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 15:00:00'},
#   {'dt': 1565373600,
#    'main': {'temp': 301.266,
#     'temp_min': 301.266,
#     'temp_max': 301.266,
#     'pressure': 1000.72,
#     'sea_level': 1000.72,
#     'grnd_level': 1000.5,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 15.45, 'deg': 246.829},
#    'rain': {'3h': 2.687},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 18:00:00'},
#   {'dt': 1565384400,
#    'main': {'temp': 301.1,
#     'temp_min': 301.1,
#     'temp_max': 301.1,
#     'pressure': 998.96,
#     'sea_level': 998.96,
#     'grnd_level': 998.6,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 15.23, 'deg': 247.631},
#    'rain': {'3h': 4},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 21:00:00'},
#   {'dt': 1565395200,
#    'main': {'temp': 301.13,
#     'temp_min': 301.13,
#     'temp_max': 301.13,
#     'pressure': 998.63,
#     'sea_level': 998.63,
#     'grnd_level': 998.36,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 15.39, 'deg': 246.551},
#    'rain': {'3h': 3.5},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 00:00:00'},
#   {'dt': 1565406000,
#    'main': {'temp': 301.368,
#     'temp_min': 301.368,
#     'temp_max': 301.368,
#     'pressure': 1001.38,
#     'sea_level': 1001.38,
#     'grnd_level': 1000.82,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 14.93, 'deg': 249.58},
#    'rain': {'3h': 1.562},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 03:00:00'},
#   {'dt': 1565416800,
#    'main': {'temp': 301.118,
#     'temp_min': 301.118,
#     'temp_max': 301.118,
#     'pressure': 1002.49,
#     'sea_level': 1002.49,
#     'grnd_level': 1001.93,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 13.46, 'deg': 252.918},
#    'rain': {'3h': 1.376},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 06:00:00'},
#   {'dt': 1565427600,
#    'main': {'temp': 300.659,
#     'temp_min': 300.659,
#     'temp_max': 300.659,
#     'pressure': 1001.48,
#     'sea_level': 1001.48,
#     'grnd_level': 1001.14,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 13.03, 'deg': 258.445},
#    'rain': {'3h': 1.25},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 09:00:00'},
#   {'dt': 1565438400,
#    'main': {'temp': 300.5,
#     'temp_min': 300.5,
#     'temp_max': 300.5,
#     'pressure': 1001.31,
#     'sea_level': 1001.31,
#     'grnd_level': 1001.22,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 12.6, 'deg': 260.37},
#    'rain': {'3h': 0.188},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 12:00:00'},
#   {'dt': 1565449200,
#    'main': {'temp': 300.542,
#     'temp_min': 300.542,
#     'temp_max': 300.542,
#     'pressure': 1002.95,
#     'sea_level': 1002.95,
#     'grnd_level': 1002.87,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 12.65, 'deg': 251.505},
#    'rain': {'3h': 1.375},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 15:00:00'},
#   {'dt': 1565460000,
#    'main': {'temp': 301.173,
#     'temp_min': 301.173,
#     'temp_max': 301.173,
#     'pressure': 1004.29,
#     'sea_level': 1004.29,
#     'grnd_level': 1003.96,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 11.72, 'deg': 246.168},
#    'rain': {'3h': 1.437},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 18:00:00'},
#   {'dt': 1565470800,
#    'main': {'temp': 300.898,
#     'temp_min': 300.898,
#     'temp_max': 300.898,
#     'pressure': 1002.61,
#     'sea_level': 1002.61,
#     'grnd_level': 1002.29,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 12.65, 'deg': 242.572},
#    'rain': {'3h': 2.25},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 21:00:00'},
#   {'dt': 1565481600,
#    'main': {'temp': 301.2,
#     'temp_min': 301.2,
#     'temp_max': 301.2,
#     'pressure': 1002.64,
#     'sea_level': 1002.64,
#     'grnd_level': 1002.26,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 80},
#    'wind': {'speed': 12.34, 'deg': 237.956},
#    'rain': {'3h': 1.188},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 00:00:00'},
#   {'dt': 1565492400,
#    'main': {'temp': 301.236,
#     'temp_min': 301.236,
#     'temp_max': 301.236,
#     'pressure': 1004.4,
#     'sea_level': 1004.4,
#     'grnd_level': 1004.06,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 12.07, 'deg': 237.306},
#    'rain': {'3h': 1.25},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-11 03:00:00'},
#   {'dt': 1565503200,
#    'main': {'temp': 301.424,
#     'temp_min': 301.424,
#     'temp_max': 301.424,
#     'pressure': 1005.23,
#     'sea_level': 1005.23,
#     'grnd_level': 1004.93,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 11.4, 'deg': 237.217},
#    'rain': {'3h': 0.562},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-11 06:00:00'},
#   {'dt': 1565514000,
#    'main': {'temp': 301.4,
#     'temp_min': 301.4,
#     'temp_max': 301.4,
#     'pressure': 1003.53,
#     'sea_level': 1003.53,
#     'grnd_level': 1003.09,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 10.74, 'deg': 239.216},
#    'rain': {'3h': 0.125},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-11 09:00:00'},
#   {'dt': 1565524800,
#    'main': {'temp': 301.3,
#     'temp_min': 301.3,
#     'temp_max': 301.3,
#     'pressure': 1003.18,
#     'sea_level': 1003.18,
#     'grnd_level': 1002.82,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 10.3, 'deg': 247.684},
#    'rain': {'3h': 0.187},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-11 12:00:00'},
#   {'dt': 1565535600,
#    'main': {'temp': 301.371,
#     'temp_min': 301.371,
#     'temp_max': 301.371,
#     'pressure': 1004.91,
#     'sea_level': 1004.91,
#     'grnd_level': 1004.7,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 41},
#    'wind': {'speed': 9.31, 'deg': 245.32},
#    'rain': {'3h': 0.188},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 15:00:00'},
#   {'dt': 1565546400,
#    'main': {'temp': 301.112,
#     'temp_min': 301.112,
#     'temp_max': 301.112,
#     'pressure': 1006.11,
#     'sea_level': 1006.11,
#     'grnd_level': 1006.01,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 39},
#    'wind': {'speed': 9.4, 'deg': 248.505},
#    'rain': {'3h': 0.187},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 18:00:00'},
#   {'dt': 1565557200,
#    'main': {'temp': 301.049,
#     'temp_min': 301.049,
#     'temp_max': 301.049,
#     'pressure': 1004.31,
#     'sea_level': 1004.31,
#     'grnd_level': 1004.13,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 8.82, 'deg': 250.212},
#    'rain': {'3h': 0.188},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 21:00:00'},
#   {'dt': 1565568000,
#    'main': {'temp': 301.18,
#     'temp_min': 301.18,
#     'temp_max': 301.18,
#     'pressure': 1004.87,
#     'sea_level': 1004.87,
#     'grnd_level': 1004.66,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 45},
#    'wind': {'speed': 8.17, 'deg': 251.11},
#    'rain': {'3h': 0.312},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-12 00:00:00'},
#   {'dt': 1565578800,
#    'main': {'temp': 301.2,
#     'temp_min': 301.2,
#     'temp_max': 301.2,
#     'pressure': 1006.46,
#     'sea_level': 1006.46,
#     'grnd_level': 1006.23,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 60},
#    'wind': {'speed': 8.11, 'deg': 257.093},
#    'rain': {'3h': 0.312},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-12 03:00:00'},
#   {'dt': 1565589600,
#    'main': {'temp': 301.34,
#     'temp_min': 301.34,
#     'temp_max': 301.34,
#     'pressure': 1007.28,
#     'sea_level': 1007.28,
#     'grnd_level': 1007.04,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 66},
#    'wind': {'speed': 8.36, 'deg': 252.137},
#    'rain': {'3h': 0.25},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-12 06:00:00'},
#   {'dt': 1565600400,
#    'main': {'temp': 301.428,
#     'temp_min': 301.428,
#     'temp_max': 301.428,
#     'pressure': 1005.5,
#     'sea_level': 1005.5,
#     'grnd_level': 1005.18,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 9.11, 'deg': 257.747},
#    'rain': {'3h': 0.188},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-12 09:00:00'},
#   {'dt': 1565611200,
#    'main': {'temp': 301.334,
#     'temp_min': 301.334,
#     'temp_max': 301.334,
#     'pressure': 1004.79,
#     'sea_level': 1004.79,
#     'grnd_level': 1004.44,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 8.6, 'deg': 254.297},
#    'rain': {'3h': 0.062},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-12 12:00:00'},
#   {'dt': 1565622000,
#    'main': {'temp': 301.234,
#     'temp_min': 301.234,
#     'temp_max': 301.234,
#     'pressure': 1006.53,
#     'sea_level': 1006.53,
#     'grnd_level': 1006.22,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 29},
#    'wind': {'speed': 8.79, 'deg': 253.432},
#    'rain': {'3h': 0.25},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-12 15:00:00'},
#   {'dt': 1565632800,
#    'main': {'temp': 301.2,
#     'temp_min': 301.2,
#     'temp_max': 301.2,
#     'pressure': 1007.5,
#     'sea_level': 1007.5,
#     'grnd_level': 1007.18,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 34},
#    'wind': {'speed': 7.91, 'deg': 247.674},
#    'rain': {'3h': 0.125},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-12 18:00:00'},
#   {'dt': 1565643600,
#    'main': {'temp': 300.878,
#     'temp_min': 300.878,
#     'temp_max': 300.878,
#     'pressure': 1005.51,
#     'sea_level': 1005.51,
#     'grnd_level': 1005.18,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.47, 'deg': 247.504},
#    'rain': {'3h': 0.438},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-12 21:00:00'},
#   {'dt': 1565654400,
#    'main': {'temp': 300.9,
#     'temp_min': 300.9,
#     'temp_max': 300.9,
#     'pressure': 1005.79,
#     'sea_level': 1005.79,
#     'grnd_level': 1005.39,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.15, 'deg': 252.725},
#    'rain': {'3h': 0.25},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-13 00:00:00'},
#   {'dt': 1565665200,
#    'main': {'temp': 301.224,
#     'temp_min': 301.224,
#     'temp_max': 301.224,
#     'pressure': 1007.36,
#     'sea_level': 1007.36,
#     'grnd_level': 1007.03,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.46, 'deg': 258.685},
#    'rain': {'3h': 0.5},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-13 03:00:00'}],
#  'Delhi': [{'dt': 1565244000,
#    'main': {'temp': 309.02,
#     'temp_min': 309.02,
#     'temp_max': 309.727,
#     'pressure': 995.49,
#     'sea_level': 995.49,
#     'grnd_level': 970.57,
#     'humidity': 42,
#     'temp_kf': -0.71},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 5.16, 'deg': 128.885},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-08 06:00:00'},
#   {'dt': 1565254800,
#    'main': {'temp': 310.88,
#     'temp_min': 310.88,
#     'temp_max': 311.411,
#     'pressure': 993.13,
#     'sea_level': 993.13,
#     'grnd_level': 968.28,
#     'humidity': 38,
#     'temp_kf': -0.53},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 5.44, 'deg': 105.02},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-08 09:00:00'},
#   {'dt': 1565265600,
#    'main': {'temp': 310.39,
#     'temp_min': 310.39,
#     'temp_max': 310.743,
#     'pressure': 991.42,
#     'sea_level': 991.42,
#     'grnd_level': 967.03,
#     'humidity': 37,
#     'temp_kf': -0.36},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 84},
#    'wind': {'speed': 6.42, 'deg': 110.762},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-08 12:00:00'},
#   {'dt': 1565276400,
#    'main': {'temp': 307.43,
#     'temp_min': 307.43,
#     'temp_max': 307.608,
#     'pressure': 993.74,
#     'sea_level': 993.74,
#     'grnd_level': 969.38,
#     'humidity': 47,
#     'temp_kf': -0.18},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 4.94, 'deg': 123.365},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-08 15:00:00'},
#   {'dt': 1565287200,
#    'main': {'temp': 306.243,
#     'temp_min': 306.243,
#     'temp_max': 306.243,
#     'pressure': 995.42,
#     'sea_level': 995.42,
#     'grnd_level': 970.79,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 6.36, 'deg': 120.315},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-08 18:00:00'},
#   {'dt': 1565298000,
#    'main': {'temp': 304.254,
#     'temp_min': 304.254,
#     'temp_max': 304.254,
#     'pressure': 995.17,
#     'sea_level': 995.17,
#     'grnd_level': 970.4,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 6.44, 'deg': 111.28},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-08 21:00:00'},
#   {'dt': 1565308800,
#    'main': {'temp': 302.848,
#     'temp_min': 302.848,
#     'temp_max': 302.848,
#     'pressure': 995.88,
#     'sea_level': 995.88,
#     'grnd_level': 970.96,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 5.67, 'deg': 95.64},
#    'rain': {'3h': 1.375},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 00:00:00'},
#   {'dt': 1565319600,
#    'main': {'temp': 304.224,
#     'temp_min': 304.224,
#     'temp_max': 304.224,
#     'pressure': 997.33,
#     'sea_level': 997.33,
#     'grnd_level': 972.17,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.48, 'deg': 87.541},
#    'rain': {'3h': 2.625},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 03:00:00'},
#   {'dt': 1565330400,
#    'main': {'temp': 308.243,
#     'temp_min': 308.243,
#     'temp_max': 308.243,
#     'pressure': 997.72,
#     'sea_level': 997.72,
#     'grnd_level': 972.43,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 86},
#    'wind': {'speed': 7.31, 'deg': 101.367},
#    'rain': {},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 06:00:00'},
#   {'dt': 1565341200,
#    'main': {'temp': 310.916,
#     'temp_min': 310.916,
#     'temp_max': 310.916,
#     'pressure': 994.7,
#     'sea_level': 994.7,
#     'grnd_level': 969.65,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 84},
#    'wind': {'speed': 6.79, 'deg': 95.567},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 09:00:00'},
#   {'dt': 1565352000,
#    'main': {'temp': 309.843,
#     'temp_min': 309.843,
#     'temp_max': 309.843,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 968.33,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 65},
#    'wind': {'speed': 7.13, 'deg': 96.256},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 12:00:00'},
#   {'dt': 1565362800,
#    'main': {'temp': 307.435,
#     'temp_min': 307.435,
#     'temp_max': 307.435,
#     'pressure': 994.6,
#     'sea_level': 994.6,
#     'grnd_level': 970.04,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 6.38, 'deg': 97.138},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 15:00:00'},
#   {'dt': 1565373600,
#    'main': {'temp': 305.466,
#     'temp_min': 305.466,
#     'temp_max': 305.466,
#     'pressure': 995.82,
#     'sea_level': 995.82,
#     'grnd_level': 971.11,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 66},
#    'wind': {'speed': 7.35, 'deg': 105.226},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 18:00:00'},
#   {'dt': 1565384400,
#    'main': {'temp': 303.9,
#     'temp_min': 303.9,
#     'temp_max': 303.9,
#     'pressure': 995.05,
#     'sea_level': 995.05,
#     'grnd_level': 970.02,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.07, 'deg': 106.399},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 21:00:00'},
#   {'dt': 1565395200,
#    'main': {'temp': 302.53,
#     'temp_min': 302.53,
#     'temp_max': 302.53,
#     'pressure': 995.14,
#     'sea_level': 995.14,
#     'grnd_level': 970.17,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 7.1, 'deg': 111.362},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 00:00:00'},
#   {'dt': 1565406000,
#    'main': {'temp': 303.668,
#     'temp_min': 303.668,
#     'temp_max': 303.668,
#     'pressure': 997.02,
#     'sea_level': 997.02,
#     'grnd_level': 971.94,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 7.43, 'deg': 115.824},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 03:00:00'},
#   {'dt': 1565416800,
#    'main': {'temp': 307.418,
#     'temp_min': 307.418,
#     'temp_max': 307.418,
#     'pressure': 997.05,
#     'sea_level': 997.05,
#     'grnd_level': 971.92,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 7.25, 'deg': 116.689},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 06:00:00'},
#   {'dt': 1565427600,
#    'main': {'temp': 309.859,
#     'temp_min': 309.859,
#     'temp_max': 309.859,
#     'pressure': 995.13,
#     'sea_level': 995.13,
#     'grnd_level': 970.15,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 6.6, 'deg': 127.648},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 09:00:00'},
#   {'dt': 1565438400,
#    'main': {'temp': 307.8,
#     'temp_min': 307.8,
#     'temp_max': 307.8,
#     'pressure': 994.22,
#     'sea_level': 994.22,
#     'grnd_level': 969.97,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 5.49, 'deg': 145.697},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 12:00:00'},
#   {'dt': 1565449200,
#    'main': {'temp': 305.941,
#     'temp_min': 305.941,
#     'temp_max': 305.941,
#     'pressure': 995.98,
#     'sea_level': 995.98,
#     'grnd_level': 971.76,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 4.4, 'deg': 135.424},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 15:00:00'},
#   {'dt': 1565460000,
#    'main': {'temp': 304.873,
#     'temp_min': 304.873,
#     'temp_max': 304.873,
#     'pressure': 997.57,
#     'sea_level': 997.57,
#     'grnd_level': 972.83,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 4.56, 'deg': 147.283},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 18:00:00'},
#   {'dt': 1565470800,
#    'main': {'temp': 302.898,
#     'temp_min': 302.898,
#     'temp_max': 302.898,
#     'pressure': 997.03,
#     'sea_level': 997.03,
#     'grnd_level': 972.53,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 45},
#    'wind': {'speed': 3.06, 'deg': 168.133},
#    'rain': {'3h': 0.062},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 21:00:00'},
#   {'dt': 1565481600,
#    'main': {'temp': 302,
#     'temp_min': 302,
#     'temp_max': 302,
#     'pressure': 997.59,
#     'sea_level': 997.59,
#     'grnd_level': 972.84,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 27},
#    'wind': {'speed': 3.17, 'deg': 152.139},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 00:00:00'},
#   {'dt': 1565492400,
#    'main': {'temp': 303.696,
#     'temp_min': 303.696,
#     'temp_max': 303.696,
#     'pressure': 998.61,
#     'sea_level': 998.61,
#     'grnd_level': 973.83,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.32, 'deg': 147.949},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-11 03:00:00'},
#   {'dt': 1565503200,
#    'main': {'temp': 307.924,
#     'temp_min': 307.924,
#     'temp_max': 307.924,
#     'pressure': 998.31,
#     'sea_level': 998.31,
#     'grnd_level': 973.58,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4, 'deg': 147.598},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-11 06:00:00'},
#   {'dt': 1565514000,
#    'main': {'temp': 309.9,
#     'temp_min': 309.9,
#     'temp_max': 309.9,
#     'pressure': 995.6,
#     'sea_level': 995.6,
#     'grnd_level': 970.96,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.12, 'deg': 176.336},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-11 09:00:00'},
#   {'dt': 1565524800,
#    'main': {'temp': 309.1,
#     'temp_min': 309.1,
#     'temp_max': 309.1,
#     'pressure': 994.75,
#     'sea_level': 994.75,
#     'grnd_level': 970.24,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.03, 'deg': 206.582},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-11 12:00:00'},
#   {'dt': 1565535600,
#    'main': {'temp': 307.071,
#     'temp_min': 307.071,
#     'temp_max': 307.071,
#     'pressure': 996.36,
#     'sea_level': 996.36,
#     'grnd_level': 971.51,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 4.07, 'deg': 231.73},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 15:00:00'},
#   {'dt': 1565546400,
#    'main': {'temp': 305.112,
#     'temp_min': 305.112,
#     'temp_max': 305.112,
#     'pressure': 998.02,
#     'sea_level': 998.02,
#     'grnd_level': 973.19,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 4.13, 'deg': 235.197},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 18:00:00'},
#   {'dt': 1565557200,
#    'main': {'temp': 303.549,
#     'temp_min': 303.549,
#     'temp_max': 303.549,
#     'pressure': 997.21,
#     'sea_level': 997.21,
#     'grnd_level': 972.51,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 2.84, 'deg': 237.277},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 21:00:00'},
#   {'dt': 1565568000,
#    'main': {'temp': 303.38,
#     'temp_min': 303.38,
#     'temp_max': 303.38,
#     'pressure': 997.88,
#     'sea_level': 997.88,
#     'grnd_level': 972.98,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 17},
#    'wind': {'speed': 2.66, 'deg': 252.62},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-12 00:00:00'},
#   {'dt': 1565578800,
#    'main': {'temp': 305.5,
#     'temp_min': 305.5,
#     'temp_max': 305.5,
#     'pressure': 999.15,
#     'sea_level': 999.15,
#     'grnd_level': 974.12,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 77},
#    'wind': {'speed': 4.73, 'deg': 272.52},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-12 03:00:00'},
#   {'dt': 1565589600,
#    'main': {'temp': 309.94,
#     'temp_min': 309.94,
#     'temp_max': 309.94,
#     'pressure': 998.94,
#     'sea_level': 998.94,
#     'grnd_level': 973.73,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 4.25, 'deg': 279.42},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-12 06:00:00'},
#   {'dt': 1565600400,
#    'main': {'temp': 310.228,
#     'temp_min': 310.228,
#     'temp_max': 310.228,
#     'pressure': 995.94,
#     'sea_level': 995.94,
#     'grnd_level': 971.03,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.03, 'deg': 266.879},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-12 09:00:00'},
#   {'dt': 1565611200,
#    'main': {'temp': 310.234,
#     'temp_min': 310.234,
#     'temp_max': 310.234,
#     'pressure': 994.69,
#     'sea_level': 994.69,
#     'grnd_level': 970.09,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 4.47, 'deg': 263.75},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-12 12:00:00'},
#   {'dt': 1565622000,
#    'main': {'temp': 308.834,
#     'temp_min': 308.834,
#     'temp_max': 308.834,
#     'pressure': 995.25,
#     'sea_level': 995.25,
#     'grnd_level': 970.92,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.04, 'deg': 251.412},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-12 15:00:00'},
#   {'dt': 1565632800,
#    'main': {'temp': 306.6,
#     'temp_min': 306.6,
#     'temp_max': 306.6,
#     'pressure': 996.37,
#     'sea_level': 996.37,
#     'grnd_level': 972.14,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 77},
#    'wind': {'speed': 5.35, 'deg': 251.64},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-12 18:00:00'},
#   {'dt': 1565643600,
#    'main': {'temp': 305.578,
#     'temp_min': 305.578,
#     'temp_max': 305.578,
#     'pressure': 995.29,
#     'sea_level': 995.29,
#     'grnd_level': 971.01,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.74, 'deg': 259.339},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-12 21:00:00'},
#   {'dt': 1565654400,
#    'main': {'temp': 304.8,
#     'temp_min': 304.8,
#     'temp_max': 304.8,
#     'pressure': 995.59,
#     'sea_level': 995.59,
#     'grnd_level': 970.78,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.6, 'deg': 266.602},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-13 00:00:00'},
#   {'dt': 1565665200,
#    'main': {'temp': 306.124,
#     'temp_min': 306.124,
#     'temp_max': 306.124,
#     'pressure': 997.16,
#     'sea_level': 997.16,
#     'grnd_level': 972.07,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 39},
#    'wind': {'speed': 7.6, 'deg': 269.405},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-13 03:00:00'}],
#  'Bangalore': [{'dt': 1565244000,
#    'main': {'temp': 298.59,
#     'temp_min': 297.127,
#     'temp_max': 298.59,
#     'pressure': 1006.81,
#     'sea_level': 1006.81,
#     'grnd_level': 911.26,
#     'humidity': 74,
#     'temp_kf': 1.47},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 11.23, 'deg': 251.668},
#    'rain': {'3h': 0.5},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-08 06:00:00'},
#   {'dt': 1565254800,
#    'main': {'temp': 298.91,
#     'temp_min': 297.811,
#     'temp_max': 298.91,
#     'pressure': 1004.75,
#     'sea_level': 1004.75,
#     'grnd_level': 909.37,
#     'humidity': 69,
#     'temp_kf': 1.1},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.78, 'deg': 260.533},
#    'rain': {'3h': 0.625},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-08 09:00:00'},
#   {'dt': 1565265600,
#    'main': {'temp': 296.98,
#     'temp_min': 296.243,
#     'temp_max': 296.98,
#     'pressure': 1004.23,
#     'sea_level': 1004.23,
#     'grnd_level': 908.91,
#     'humidity': 77,
#     'temp_kf': 0.73},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.77, 'deg': 253.372},
#    'rain': {'3h': 0.187},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-08 12:00:00'},
#   {'dt': 1565276400,
#    'main': {'temp': 295.57,
#     'temp_min': 295.208,
#     'temp_max': 295.57,
#     'pressure': 1006.89,
#     'sea_level': 1006.89,
#     'grnd_level': 910.71,
#     'humidity': 80,
#     'temp_kf': 0.37},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.31, 'deg': 250.892},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-08 15:00:00'},
#   {'dt': 1565287200,
#    'main': {'temp': 294.343,
#     'temp_min': 294.343,
#     'temp_max': 294.343,
#     'pressure': 1007.59,
#     'sea_level': 1007.59,
#     'grnd_level': 911.65,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.17, 'deg': 249.345},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-08 18:00:00'},
#   {'dt': 1565298000,
#    'main': {'temp': 293.704,
#     'temp_min': 293.704,
#     'temp_max': 293.704,
#     'pressure': 1005.69,
#     'sea_level': 1005.69,
#     'grnd_level': 909.71,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.85, 'deg': 247.698},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-08 21:00:00'},
#   {'dt': 1565308800,
#    'main': {'temp': 293.628,
#     'temp_min': 293.628,
#     'temp_max': 293.628,
#     'pressure': 1005.55,
#     'sea_level': 1005.55,
#     'grnd_level': 909.81,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.77, 'deg': 245.533},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 00:00:00'},
#   {'dt': 1565319600,
#    'main': {'temp': 296.134,
#     'temp_min': 296.134,
#     'temp_max': 296.134,
#     'pressure': 1007.53,
#     'sea_level': 1007.53,
#     'grnd_level': 911.53,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 9.75, 'deg': 247.808},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 03:00:00'},
#   {'dt': 1565330400,
#    'main': {'temp': 299.443,
#     'temp_min': 299.443,
#     'temp_max': 299.443,
#     'pressure': 1007.67,
#     'sea_level': 1007.67,
#     'grnd_level': 911.93,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 10.1, 'deg': 256.195},
#    'rain': {'3h': 0.375},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 06:00:00'},
#   {'dt': 1565341200,
#    'main': {'temp': 300.416,
#     'temp_min': 300.416,
#     'temp_max': 300.416,
#     'pressure': 1005.66,
#     'sea_level': 1005.66,
#     'grnd_level': 910.63,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 10.52, 'deg': 257.765},
#    'rain': {'3h': 0.5},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 09:00:00'},
#   {'dt': 1565352000,
#    'main': {'temp': 299.043,
#     'temp_min': 299.043,
#     'temp_max': 299.043,
#     'pressure': 1005.46,
#     'sea_level': 1005.46,
#     'grnd_level': 910.19,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 9.71, 'deg': 265.941},
#    'rain': {'3h': 0.312},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 12:00:00'},
#   {'dt': 1565362800,
#    'main': {'temp': 296.235,
#     'temp_min': 296.235,
#     'temp_max': 296.235,
#     'pressure': 1008.58,
#     'sea_level': 1008.58,
#     'grnd_level': 912.61,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 70},
#    'wind': {'speed': 6.87, 'deg': 254.519},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 15:00:00'},
#   {'dt': 1565373600,
#    'main': {'temp': 295.266,
#     'temp_min': 295.266,
#     'temp_max': 295.266,
#     'pressure': 1009.35,
#     'sea_level': 1009.35,
#     'grnd_level': 913.29,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 74},
#    'wind': {'speed': 7.3, 'deg': 256.777},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 18:00:00'},
#   {'dt': 1565384400,
#    'main': {'temp': 294.1,
#     'temp_min': 294.1,
#     'temp_max': 294.1,
#     'pressure': 1007.01,
#     'sea_level': 1007.01,
#     'grnd_level': 910.97,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 70},
#    'wind': {'speed': 7.31, 'deg': 249.447},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 21:00:00'},
#   {'dt': 1565395200,
#    'main': {'temp': 293.57,
#     'temp_min': 293.57,
#     'temp_max': 293.57,
#     'pressure': 1006.31,
#     'sea_level': 1006.31,
#     'grnd_level': 910.42,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 74},
#    'wind': {'speed': 7.43, 'deg': 253.702},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 00:00:00'},
#   {'dt': 1565406000,
#    'main': {'temp': 296.168,
#     'temp_min': 296.168,
#     'temp_max': 296.168,
#     'pressure': 1008.76,
#     'sea_level': 1008.76,
#     'grnd_level': 912.87,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 59},
#    'wind': {'speed': 9.13, 'deg': 258.775},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 03:00:00'},
#   {'dt': 1565416800,
#    'main': {'temp': 300.618,
#     'temp_min': 300.618,
#     'temp_max': 300.618,
#     'pressure': 1007.93,
#     'sea_level': 1007.93,
#     'grnd_level': 912.44,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 53},
#    'wind': {'speed': 10.26, 'deg': 266.345},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 06:00:00'},
#   {'dt': 1565427600,
#    'main': {'temp': 302.059,
#     'temp_min': 302.059,
#     'temp_max': 302.059,
#     'pressure': 1005.75,
#     'sea_level': 1005.75,
#     'grnd_level': 910.58,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 63},
#    'wind': {'speed': 9.82, 'deg': 270.875},
#    'rain': {'3h': 0.125},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 09:00:00'},
#   {'dt': 1565438400,
#    'main': {'temp': 299,
#     'temp_min': 299,
#     'temp_max': 299,
#     'pressure': 1006.33,
#     'sea_level': 1006.33,
#     'grnd_level': 911.07,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 8.84, 'deg': 271.699},
#    'rain': {'3h': 0.187},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 12:00:00'},
#   {'dt': 1565449200,
#    'main': {'temp': 296.242,
#     'temp_min': 296.242,
#     'temp_max': 296.242,
#     'pressure': 1009.14,
#     'sea_level': 1009.14,
#     'grnd_level': 913.27,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.39, 'deg': 262.606},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 15:00:00'},
#   {'dt': 1565460000,
#    'main': {'temp': 295.273,
#     'temp_min': 295.273,
#     'temp_max': 295.273,
#     'pressure': 1010.3,
#     'sea_level': 1010.3,
#     'grnd_level': 914.22,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.62, 'deg': 263.632},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 18:00:00'},
#   {'dt': 1565470800,
#    'main': {'temp': 294.598,
#     'temp_min': 294.598,
#     'temp_max': 294.598,
#     'pressure': 1008.61,
#     'sea_level': 1008.61,
#     'grnd_level': 912.42,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 7.03, 'deg': 267.488},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 21:00:00'},
#   {'dt': 1565481600,
#    'main': {'temp': 294,
#     'temp_min': 294,
#     'temp_max': 294,
#     'pressure': 1008.27,
#     'sea_level': 1008.27,
#     'grnd_level': 911.99,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 6.7, 'deg': 266.511},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 00:00:00'},
#   {'dt': 1565492400,
#    'main': {'temp': 295.366,
#     'temp_min': 295.366,
#     'temp_max': 295.366,
# ...
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.58, 'deg': 252.163},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-08 21:00:00'},
#   {'dt': 1565308800,
#    'main': {'temp': 297.368,
#     'temp_min': 297.368,
#     'temp_max': 297.368,
#     'pressure': 1000.88,
#     'sea_level': 1000.88,
#     'grnd_level': 947.81,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.06, 'deg': 253.004},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 00:00:00'},
#   {'dt': 1565319600,
#    'main': {'temp': 299.314,
#     'temp_min': 299.314,
#     'temp_max': 299.314,
#     'pressure': 1002.85,
#     'sea_level': 1002.85,
#     'grnd_level': 949.65,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 12.24, 'deg': 254.349},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 03:00:00'},
#   {'dt': 1565330400,
#    'main': {'temp': 302.443,
#     'temp_min': 302.443,
#     'temp_max': 302.443,
#     'pressure': 1003.32,
#     'sea_level': 1003.32,
#     'grnd_level': 950.19,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 14.68, 'deg': 254.466},
#    'rain': {'3h': 0.25},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 06:00:00'},
#   {'dt': 1565341200,
#    'main': {'temp': 302.416,
#     'temp_min': 302.416,
#     'temp_max': 302.416,
#     'pressure': 1002.35,
#     'sea_level': 1002.35,
#     'grnd_level': 949.17,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 14.84, 'deg': 253.081},
#    'rain': {'3h': 0.375},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 09:00:00'},
#   {'dt': 1565352000,
#    'main': {'temp': 300.743,
#     'temp_min': 300.743,
#     'temp_max': 300.743,
#     'pressure': 1001.61,
#     'sea_level': 1001.61,
#     'grnd_level': 948.56,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 13.27, 'deg': 254.983},
#    'rain': {'3h': 0.437},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-09 12:00:00'},
#   {'dt': 1565362800,
#    'main': {'temp': 298.435,
#     'temp_min': 298.435,
#     'temp_max': 298.435,
#     'pressure': 1003.71,
#     'sea_level': 1003.71,
#     'grnd_level': 950.37,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 10.72, 'deg': 245.568},
#    'rain': {'3h': 0.188},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 15:00:00'},
#   {'dt': 1565373600,
#    'main': {'temp': 297.866,
#     'temp_min': 297.866,
#     'temp_max': 297.866,
#     'pressure': 1004.61,
#     'sea_level': 1004.61,
#     'grnd_level': 951.25,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 10.24, 'deg': 240.518},
#    'rain': {'3h': 0.124},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 18:00:00'},
#   {'dt': 1565384400,
#    'main': {'temp': 297.3,
#     'temp_min': 297.3,
#     'temp_max': 297.3,
#     'pressure': 1003.07,
#     'sea_level': 1003.07,
#     'grnd_level': 949.8,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.05, 'deg': 243.155},
#    'rain': {'3h': 0.188},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-09 21:00:00'},
#   {'dt': 1565395200,
#    'main': {'temp': 296.88,
#     'temp_min': 296.88,
#     'temp_max': 296.88,
#     'pressure': 1002.82,
#     'sea_level': 1002.82,
#     'grnd_level': 949.42,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.25, 'deg': 240.5},
#    'rain': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 00:00:00'},
#   {'dt': 1565406000,
#    'main': {'temp': 298.268,
#     'temp_min': 298.268,
#     'temp_max': 298.268,
#     'pressure': 1004.97,
#     'sea_level': 1004.97,
#     'grnd_level': 951.59,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 11.17, 'deg': 243.878},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 03:00:00'},
#   {'dt': 1565416800,
#    'main': {'temp': 301.818,
#     'temp_min': 301.818,
#     'temp_max': 301.818,
#     'pressure': 1004.9,
#     'sea_level': 1004.9,
#     'grnd_level': 951.93,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 13.37, 'deg': 250.176},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 06:00:00'},
#   {'dt': 1565427600,
#    'main': {'temp': 303.059,
#     'temp_min': 303.059,
#     'temp_max': 303.059,
#     'pressure': 1003.33,
#     'sea_level': 1003.33,
#     'grnd_level': 950.34,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 48},
#    'wind': {'speed': 13.38, 'deg': 251.478},
#    'rain': {'3h': 0.312},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 09:00:00'},
#   {'dt': 1565438400,
#    'main': {'temp': 301.3,
#     'temp_min': 301.3,
#     'temp_max': 301.3,
#     'pressure': 1003.81,
#     'sea_level': 1003.81,
#     'grnd_level': 950.53,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 40},
#    'wind': {'speed': 11.88, 'deg': 253.029},
#    'rain': {'3h': 0.376},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-10 12:00:00'},
#   {'dt': 1565449200,
#    'main': {'temp': 298.742,
#     'temp_min': 298.742,
#     'temp_max': 298.742,
#     'pressure': 1006.29,
#     'sea_level': 1006.29,
#     'grnd_level': 952.64,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 84},
#    'wind': {'speed': 9.22, 'deg': 246.857},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 15:00:00'},
#   {'dt': 1565460000,
#    'main': {'temp': 298.373,
#     'temp_min': 298.373,
#     'temp_max': 298.373,
#     'pressure': 1007.46,
#     'sea_level': 1007.46,
#     'grnd_level': 953.79,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 7.46, 'deg': 250.557},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 18:00:00'},
#   {'dt': 1565470800,
#    'main': {'temp': 297.698,
#     'temp_min': 297.698,
#     'temp_max': 297.698,
#     'pressure': 1005.98,
#     'sea_level': 1005.98,
#     'grnd_level': 952.34,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 76},
#    'wind': {'speed': 6.99, 'deg': 251.425},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-10 21:00:00'},
#   {'dt': 1565481600,
#    'main': {'temp': 296.5,
#     'temp_min': 296.5,
#     'temp_max': 296.5,
#     'pressure': 1006.31,
#     'sea_level': 1006.31,
#     'grnd_level': 952.7,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 60},
#    'wind': {'speed': 5.91, 'deg': 248.058},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 00:00:00'},
#   {'dt': 1565492400,
#    'main': {'temp': 299.006,
#     'temp_min': 299.006,
#     'temp_max': 299.006,
#     'pressure': 1007.58,
#     'sea_level': 1007.58,
#     'grnd_level': 954.09,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 7.88, 'deg': 251.42},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-11 03:00:00'},
#   {'dt': 1565503200,
#    'main': {'temp': 302.524,
#     'temp_min': 302.524,
#     'temp_max': 302.524,
#     'pressure': 1007.39,
#     'sea_level': 1007.39,
#     'grnd_level': 954.18,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 24},
#    'wind': {'speed': 8.48, 'deg': 254.436},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-11 06:00:00'},
#   {'dt': 1565514000,
#    'main': {'temp': 303.6,
#     'temp_min': 303.6,
#     'temp_max': 303.6,
#     'pressure': 1004.75,
#     'sea_level': 1004.75,
#     'grnd_level': 951.59,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 9.78, 'deg': 251.113},
#    'rain': {'3h': 0.25},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-11 09:00:00'},
#   {'dt': 1565524800,
#    'main': {'temp': 302,
#     'temp_min': 302,
#     'temp_max': 302,
#     'pressure': 1004.58,
#     'sea_level': 1004.58,
#     'grnd_level': 951.34,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 79},
#    'wind': {'speed': 9.39, 'deg': 255.766},
#    'rain': {'3h': 0.188},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-11 12:00:00'},
#   {'dt': 1565535600,
#    'main': {'temp': 299.271,
#     'temp_min': 299.271,
#     'temp_max': 299.271,
#     'pressure': 1007.36,
#     'sea_level': 1007.36,
#     'grnd_level': 953.61,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 86},
#    'wind': {'speed': 6.57, 'deg': 253.016},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 15:00:00'},
#   {'dt': 1565546400,
#    'main': {'temp': 298.212,
#     'temp_min': 298.212,
#     'temp_max': 298.212,
#     'pressure': 1008.56,
#     'sea_level': 1008.56,
#     'grnd_level': 954.65,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 6.33, 'deg': 254.267},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 18:00:00'},
#   {'dt': 1565557200,
#    'main': {'temp': 297.449,
#     'temp_min': 297.449,
#     'temp_max': 297.449,
#     'pressure': 1006.66,
#     'sea_level': 1006.66,
#     'grnd_level': 952.83,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 53},
#    'wind': {'speed': 5.44, 'deg': 254.799},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-11 21:00:00'},
#   {'dt': 1565568000,
#    'main': {'temp': 296.98,
#     'temp_min': 296.98,
#     'temp_max': 296.98,
#     'pressure': 1007.44,
#     'sea_level': 1007.44,
#     'grnd_level': 953.41,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 52},
#    'wind': {'speed': 4.49, 'deg': 260.706},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-12 00:00:00'},
#   {'dt': 1565578800,
#    'main': {'temp': 299,
#     'temp_min': 299,
#     'temp_max': 299,
#     'pressure': 1008.95,
#     'sea_level': 1008.95,
#     'grnd_level': 955.11,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 5.9, 'deg': 270.564},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-12 03:00:00'},
#   {'dt': 1565589600,
#    'main': {'temp': 302.24,
#     'temp_min': 302.24,
#     'temp_max': 302.24,
#     'pressure': 1008.58,
#     'sea_level': 1008.58,
#     'grnd_level': 955.14,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 26},
#    'wind': {'speed': 6.01, 'deg': 271.192},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-12 06:00:00'},
#   {'dt': 1565600400,
#    'main': {'temp': 304.328,
#     'temp_min': 304.328,
#     'temp_max': 304.328,
#     'pressure': 1005.67,
#     'sea_level': 1005.67,
#     'grnd_level': 952.23,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 7.8, 'deg': 274.237},
#    'rain': {'3h': 0.375},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-12 09:00:00'},
#   {'dt': 1565611200,
#    'main': {'temp': 303.534,
#     'temp_min': 303.534,
#     'temp_max': 303.534,
#     'pressure': 1005.25,
#     'sea_level': 1005.25,
#     'grnd_level': 951.74,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 8.44, 'deg': 270.292},
#    'rain': {'3h': 2.125},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-12 12:00:00'},
#   {'dt': 1565622000,
#    'main': {'temp': 300.234,
#     'temp_min': 300.234,
#     'temp_max': 300.234,
#     'pressure': 1007.9,
#     'sea_level': 1007.9,
#     'grnd_level': 954.15,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 7.83, 'deg': 264.746},
#    'rain': {'3h': 0.625},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-12 15:00:00'},
#   {'dt': 1565632800,
#    'main': {'temp': 298.6,
#     'temp_min': 298.6,
#     'temp_max': 298.6,
#     'pressure': 1008.95,
#     'sea_level': 1008.95,
#     'grnd_level': 955.3,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 6.83, 'deg': 263.304},
#    'rain': {},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-12 18:00:00'},
#   {'dt': 1565643600,
#    'main': {'temp': 297.578,
#     'temp_min': 297.578,
#     'temp_max': 297.578,
#     'pressure': 1007.09,
#     'sea_level': 1007.09,
#     'grnd_level': 953.5,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 5.84, 'deg': 262.714},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-12 21:00:00'},
#   {'dt': 1565654400,
#    'main': {'temp': 297,
#     'temp_min': 297,
#     'temp_max': 297,
#     'pressure': 1007.64,
#     'sea_level': 1007.64,
#     'grnd_level': 953.95,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.88, 'deg': 254.656},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2019-08-13 00:00:00'},
#   {'dt': 1565665200,
#    'main': {'temp': 298.624,
#     'temp_min': 298.624,
#     'temp_max': 298.624,
#     'pressure': 1009.36,
#     'sea_level': 1009.36,
#     'grnd_level': 955.7,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.45, 'deg': 263.238},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2019-08-13 03:00:00'}]}

# %%
#json to table
def city_table(city):
    y =  json_normalize(forecast_data[city])
    y['city'] = city
    return y

# %%
#concat tables
y = pd.DataFrame()
z = pd.DataFrame()
for city in forecast_dict1.keys():
    y = city_table(city)
    z = pd.concat([z,y], ignore_index=True)

# %%
z #all rows mapped with respective cities in city column
# Out:
#       clouds.all          dt               dt_txt  main.grnd_level  \
# 0            100  1565244000  2019-08-08 06:00:00          1001.17
# 1             98  1565254800  2019-08-08 09:00:00           999.41
# 2             99  1565265600  2019-08-08 12:00:00           998.17
# 3            100  1565276400  2019-08-08 15:00:00          1000.09
# 4            100  1565287200  2019-08-08 18:00:00          1000.29
# 5            100  1565298000  2019-08-08 21:00:00           998.59
# 6            100  1565308800  2019-08-09 00:00:00           998.48
# 7            100  1565319600  2019-08-09 03:00:00          1000.06
# 8            100  1565330400  2019-08-09 06:00:00          1001.27
# 9            100  1565341200  2019-08-09 09:00:00          1000.55
# 10           100  1565352000  2019-08-09 12:00:00           998.70
# 11           100  1565362800  2019-08-09 15:00:00           999.75
# 12           100  1565373600  2019-08-09 18:00:00          1000.50
# 13           100  1565384400  2019-08-09 21:00:00           998.60
# 14           100  1565395200  2019-08-10 00:00:00           998.36
# 15           100  1565406000  2019-08-10 03:00:00          1000.82
# 16           100  1565416800  2019-08-10 06:00:00          1001.93
# 17           100  1565427600  2019-08-10 09:00:00          1001.14
# 18           100  1565438400  2019-08-10 12:00:00          1001.22
# 19           100  1565449200  2019-08-10 15:00:00          1002.87
# 20           100  1565460000  2019-08-10 18:00:00          1003.96
# 21            99  1565470800  2019-08-10 21:00:00          1002.29
# 22            80  1565481600  2019-08-11 00:00:00          1002.26
# 23             5  1565492400  2019-08-11 03:00:00          1004.06
# 24            20  1565503200  2019-08-11 06:00:00          1004.93
# 25             3  1565514000  2019-08-11 09:00:00          1003.09
# 26            12  1565524800  2019-08-11 12:00:00          1002.82
# 27            41  1565535600  2019-08-11 15:00:00          1004.70
# 28            39  1565546400  2019-08-11 18:00:00          1006.01
# 29            16  1565557200  2019-08-11 21:00:00          1004.13
# ...          ...         ...                  ...              ...
# 1730         100  1565352000  2019-08-09 12:00:00           948.56
# 1731         100  1565362800  2019-08-09 15:00:00           950.37
# 1732         100  1565373600  2019-08-09 18:00:00           951.25
# 1733         100  1565384400  2019-08-09 21:00:00           949.80
# 1734         100  1565395200  2019-08-10 00:00:00           949.42
# 1735         100  1565406000  2019-08-10 03:00:00           951.59
# 1736          82  1565416800  2019-08-10 06:00:00           951.93
# 1737          48  1565427600  2019-08-10 09:00:00           950.34
# 1738          40  1565438400  2019-08-10 12:00:00           950.53
# 1739          84  1565449200  2019-08-10 15:00:00           952.64
# 1740          92  1565460000  2019-08-10 18:00:00           953.79
# 1741          76  1565470800  2019-08-10 21:00:00           952.34
# 1742          60  1565481600  2019-08-11 00:00:00           952.70
# 1743          10  1565492400  2019-08-11 03:00:00           954.09
# 1744          24  1565503200  2019-08-11 06:00:00           954.18
# 1745          81  1565514000  2019-08-11 09:00:00           951.59
# 1746          79  1565524800  2019-08-11 12:00:00           951.34
# 1747          86  1565535600  2019-08-11 15:00:00           953.61
# 1748          92  1565546400  2019-08-11 18:00:00           954.65
# 1749          53  1565557200  2019-08-11 21:00:00           952.83
# 1750          52  1565568000  2019-08-12 00:00:00           953.41
# 1751          15  1565578800  2019-08-12 03:00:00           955.11
# 1752          26  1565589600  2019-08-12 06:00:00           955.14
# 1753          82  1565600400  2019-08-12 09:00:00           952.23
# 1754          67  1565611200  2019-08-12 12:00:00           951.74
# 1755          97  1565622000  2019-08-12 15:00:00           954.15
# 1756          97  1565632800  2019-08-12 18:00:00           955.30
# 1757          99  1565643600  2019-08-12 21:00:00           953.50
# 1758         100  1565654400  2019-08-13 00:00:00           953.95
# 1759         100  1565665200  2019-08-13 03:00:00           955.70
#
#       main.humidity  main.pressure  main.sea_level  main.temp  main.temp_kf  \
# 0                83        1001.23         1001.23    302.060          0.53
# 1                82         999.63          999.63    301.910          0.40
# 2                82         998.36          998.36    301.710          0.26
# 3                82        1000.24         1000.24    301.640          0.13
# 4                82        1000.38         1000.38    301.343          0.00
# 5                82         998.76          998.76    301.344          0.00
# 6                82         998.70          998.70    301.378          0.00
# 7                82        1000.43         1000.43    301.424          0.00
# 8                85        1001.38         1001.38    300.543          0.00
# 9                85        1000.82         1000.82    300.416          0.00
# 10               82         998.93          998.93    301.243          0.00
# 11               81        1000.03         1000.03    301.435          0.00
# 12               81        1000.72         1000.72    301.266          0.00
# 13               81         998.96          998.96    301.100          0.00
# 14               80         998.63          998.63    301.130          0.00
# 15               80        1001.38         1001.38    301.368          0.00
# 16               78        1002.49         1002.49    301.118          0.00
# 17               80        1001.48         1001.48    300.659          0.00
# 18               78        1001.31         1001.31    300.500          0.00
# 19               82        1002.95         1002.95    300.542          0.00
# 20               80        1004.29         1004.29    301.173          0.00
# 21               80        1002.61         1002.61    300.898          0.00
# 22               80        1002.64         1002.64    301.200          0.00
# 23               79        1004.40         1004.40    301.236          0.00
# 24               80        1005.23         1005.23    301.424          0.00
# 25               80        1003.53         1003.53    301.400          0.00
# 26               81        1003.18         1003.18    301.300          0.00
# 27               81        1004.91         1004.91    301.371          0.00
# 28               81        1006.11         1006.11    301.112          0.00
# 29               81        1004.31         1004.31    301.049          0.00
# ...             ...            ...             ...        ...           ...
# 1730             65        1001.61         1001.61    300.743          0.00
# 1731             75        1003.71         1003.71    298.435          0.00
# 1732             79        1004.61         1004.61    297.866          0.00
# 1733             79        1003.07         1003.07    297.300          0.00
# 1734             81        1002.82         1002.82    296.880          0.00
# 1735             76        1004.97         1004.97    298.268          0.00
# 1736             63        1004.90         1004.90    301.818          0.00
# 1737             57        1003.33         1003.33    303.059          0.00
# 1738             62        1003.81         1003.81    301.300          0.00
# 1739             73        1006.29         1006.29    298.742          0.00
# 1740             74        1007.46         1007.46    298.373          0.00
# 1741             76        1005.98         1005.98    297.698          0.00
# 1742             82        1006.31         1006.31    296.500          0.00
# 1743             71        1007.58         1007.58    299.006          0.00
# 1744             56        1007.39         1007.39    302.524          0.00
# 1745             53        1004.75         1004.75    303.600          0.00
# 1746             58        1004.58         1004.58    302.000          0.00
# 1747             71        1007.36         1007.36    299.271          0.00
# 1748             75        1008.56         1008.56    298.212          0.00
# 1749             78        1006.66         1006.66    297.449          0.00
# 1750             81        1007.44         1007.44    296.980          0.00
# 1751             73        1008.95         1008.95    299.000          0.00
# 1752             59        1008.58         1008.58    302.240          0.00
# 1753             53        1005.67         1005.67    304.328          0.00
# 1754             55        1005.25         1005.25    303.534          0.00
# 1755             68        1007.90         1007.90    300.234          0.00
# 1756             74        1008.95         1008.95    298.600          0.00
# 1757             77        1007.09         1007.09    297.578          0.00
# 1758             80        1007.64         1007.64    297.000          0.00
# 1759             73        1009.36         1009.36    298.624          0.00
#
#       main.temp_max  main.temp_min  rain.3h sys.pod  \
# 0           302.060        301.527    0.812       d
# 1           301.910        301.511    0.625       d
# 2           301.710        301.443    0.750       d
# 3           301.640        301.508    1.062       n
# 4           301.343        301.343    0.876       n
# 5           301.344        301.344    0.438       n
# 6           301.378        301.378    1.000       n
# 7           301.424        301.424    3.375       d
# 8           300.543        300.543    5.250       d
# 9           300.416        300.416    9.312       d
# 10          301.243        301.243    4.376       d
# 11          301.435        301.435    2.688       n
# 12          301.266        301.266    2.687       n
# 13          301.100        301.100    4.000       n
# 14          301.130        301.130    3.500       n
# 15          301.368        301.368    1.562       d
# 16          301.118        301.118    1.376       d
# 17          300.659        300.659    1.250       d
# 18          300.500        300.500    0.188       d
# 19          300.542        300.542    1.375       n
# 20          301.173        301.173    1.437       n
# 21          300.898        300.898    2.250       n
# 22          301.200        301.200    1.188       n
# 23          301.236        301.236    1.250       d
# 24          301.424        301.424    0.562       d
# 25          301.400        301.400    0.125       d
# 26          301.300        301.300    0.187       d
# 27          301.371        301.371    0.188       n
# 28          301.112        301.112    0.187       n
# 29          301.049        301.049    0.188       n
# ...             ...            ...      ...     ...
# 1730        300.743        300.743    0.437       d
# 1731        298.435        298.435    0.188       n
# 1732        297.866        297.866    0.124       n
# 1733        297.300        297.300    0.188       n
# 1734        296.880        296.880      NaN       n
# 1735        298.268        298.268      NaN       d
# 1736        301.818        301.818      NaN       d
# 1737        303.059        303.059    0.312       d
# 1738        301.300        301.300    0.376       d
# 1739        298.742        298.742      NaN       n
# 1740        298.373        298.373      NaN       n
# 1741        297.698        297.698      NaN       n
# 1742        296.500        296.500      NaN       n
# 1743        299.006        299.006      NaN       d
# 1744        302.524        302.524      NaN       d
# 1745        303.600        303.600    0.250       d
# 1746        302.000        302.000    0.188       d
# 1747        299.271        299.271      NaN       n
# 1748        298.212        298.212      NaN       n
# 1749        297.449        297.449      NaN       n
# 1750        296.980        296.980      NaN       n
# 1751        299.000        299.000      NaN       d
# 1752        302.240        302.240      NaN       d
# 1753        304.328        304.328    0.375       d
# 1754        303.534        303.534    2.125       d
# 1755        300.234        300.234    0.625       n
# 1756        298.600        298.600      NaN       n
# 1757        297.578        297.578      NaN       n
# 1758        297.000        297.000      NaN       n
# 1759        298.624        298.624      NaN       d
#
#                                                 weather  wind.deg  wind.speed  \
# 0     [{'id': 500, 'main': 'Rain', 'description': 'l...   256.134       11.61
# 1     [{'id': 500, 'main': 'Rain', 'description': 'l...   253.805       11.51
# 2     [{'id': 500, 'main': 'Rain', 'description': 'l...   255.915       11.73
# 3     [{'id': 500, 'main': 'Rain', 'description': 'l...   256.545       12.07
# 4     [{'id': 500, 'main': 'Rain', 'description': 'l...   256.006       13.27
# 5     [{'id': 500, 'main': 'Rain', 'description': 'l...   254.198       13.10
# 6     [{'id': 500, 'main': 'Rain', 'description': 'l...   254.360       12.38
# 7     [{'id': 501, 'main': 'Rain', 'description': 'm...   252.941       13.17
# 8     [{'id': 501, 'main': 'Rain', 'description': 'm...   258.996       14.57
# 9     [{'id': 501, 'main': 'Rain', 'description': 'm...   248.951       14.89
# 10    [{'id': 501, 'main': 'Rain', 'description': 'm...   248.828       14.36
# 11    [{'id': 500, 'main': 'Rain', 'description': 'l...   249.291       14.43
# 12    [{'id': 500, 'main': 'Rain', 'description': 'l...   246.829       15.45
# 13    [{'id': 501, 'main': 'Rain', 'description': 'm...   247.631       15.23
# 14    [{'id': 501, 'main': 'Rain', 'description': 'm...   246.551       15.39
# 15    [{'id': 500, 'main': 'Rain', 'description': 'l...   249.580       14.93
# 16    [{'id': 500, 'main': 'Rain', 'description': 'l...   252.918       13.46
# 17    [{'id': 500, 'main': 'Rain', 'description': 'l...   258.445       13.03
# 18    [{'id': 500, 'main': 'Rain', 'description': 'l...   260.370       12.60
# 19    [{'id': 500, 'main': 'Rain', 'description': 'l...   251.505       12.65
# 20    [{'id': 500, 'main': 'Rain', 'description': 'l...   246.168       11.72
# 21    [{'id': 500, 'main': 'Rain', 'description': 'l...   242.572       12.65
# 22    [{'id': 500, 'main': 'Rain', 'description': 'l...   237.956       12.34
# 23    [{'id': 500, 'main': 'Rain', 'description': 'l...   237.306       12.07
# 24    [{'id': 500, 'main': 'Rain', 'description': 'l...   237.217       11.40
# 25    [{'id': 500, 'main': 'Rain', 'description': 'l...   239.216       10.74
# 26    [{'id': 500, 'main': 'Rain', 'description': 'l...   247.684       10.30
# 27    [{'id': 500, 'main': 'Rain', 'description': 'l...   245.320        9.31
# 28    [{'id': 500, 'main': 'Rain', 'description': 'l...   248.505        9.40
# 29    [{'id': 500, 'main': 'Rain', 'description': 'l...   250.212        8.82
# ...                                                 ...       ...         ...
# 1730  [{'id': 500, 'main': 'Rain', 'description': 'l...   254.983       13.27
# 1731  [{'id': 500, 'main': 'Rain', 'description': 'l...   245.568       10.72
# 1732  [{'id': 500, 'main': 'Rain', 'description': 'l...   240.518       10.24
# 1733  [{'id': 500, 'main': 'Rain', 'description': 'l...   243.155        9.05
# 1734  [{'id': 804, 'main': 'Clouds', 'description': ...   240.500        9.25
# 1735  [{'id': 804, 'main': 'Clouds', 'description': ...   243.878       11.17
# 1736  [{'id': 803, 'main': 'Clouds', 'description': ...   250.176       13.37
# 1737  [{'id': 500, 'main': 'Rain', 'description': 'l...   251.478       13.38
# 1738  [{'id': 500, 'main': 'Rain', 'description': 'l...   253.029       11.88
# 1739  [{'id': 803, 'main': 'Clouds', 'description': ...   246.857        9.22
# 1740  [{'id': 804, 'main': 'Clouds', 'description': ...   250.557        7.46
# 1741  [{'id': 803, 'main': 'Clouds', 'description': ...   251.425        6.99
# 1742  [{'id': 803, 'main': 'Clouds', 'description': ...   248.058        5.91
# 1743  [{'id': 800, 'main': 'Clear', 'description': '...   251.420        7.88
# 1744  [{'id': 801, 'main': 'Clouds', 'description': ...   254.436        8.48
# 1745  [{'id': 500, 'main': 'Rain', 'description': 'l...   251.113        9.78
# 1746  [{'id': 500, 'main': 'Rain', 'description': 'l...   255.766        9.39
# 1747  [{'id': 804, 'main': 'Clouds', 'description': ...   253.016        6.57
# 1748  [{'id': 804, 'main': 'Clouds', 'description': ...   254.267        6.33
# 1749  [{'id': 803, 'main': 'Clouds', 'description': ...   254.799        5.44
# 1750  [{'id': 803, 'main': 'Clouds', 'description': ...   260.706        4.49
# 1751  [{'id': 801, 'main': 'Clouds', 'description': ...   270.564        5.90
# 1752  [{'id': 802, 'main': 'Clouds', 'description': ...   271.192        6.01
# 1753  [{'id': 500, 'main': 'Rain', 'description': 'l...   274.237        7.80
# 1754  [{'id': 500, 'main': 'Rain', 'description': 'l...   270.292        8.44
# 1755  [{'id': 500, 'main': 'Rain', 'description': 'l...   264.746        7.83
# 1756  [{'id': 804, 'main': 'Clouds', 'description': ...   263.304        6.83
# 1757  [{'id': 804, 'main': 'Clouds', 'description': ...   262.714        5.84
# 1758  [{'id': 804, 'main': 'Clouds', 'description': ...   254.656        4.88
# 1759  [{'id': 804, 'main': 'Clouds', 'description': ...   263.238        6.45
#
#          city
# 0      Mumbai
# 1      Mumbai
# 2      Mumbai
# 3      Mumbai
# 4      Mumbai
# 5      Mumbai
# 6      Mumbai
# 7      Mumbai
# 8      Mumbai
# 9      Mumbai
# 10     Mumbai
# 11     Mumbai
# 12     Mumbai
# 13     Mumbai
# 14     Mumbai
# 15     Mumbai
# 16     Mumbai
# 17     Mumbai
# 18     Mumbai
# 19     Mumbai
# 20     Mumbai
# 21     Mumbai
# 22     Mumbai
# 23     Mumbai
# 24     Mumbai
# 25     Mumbai
# 26     Mumbai
# 27     Mumbai
# 28     Mumbai
# 29     Mumbai
# ...       ...
# 1730  Solapur
# 1731  Solapur
# 1732  Solapur
# 1733  Solapur
# 1734  Solapur
# 1735  Solapur
# 1736  Solapur
# 1737  Solapur
# 1738  Solapur
# 1739  Solapur
# 1740  Solapur
# 1741  Solapur
# 1742  Solapur
# 1743  Solapur
# 1744  Solapur
# 1745  Solapur
# 1746  Solapur
# 1747  Solapur
# 1748  Solapur
# 1749  Solapur
# 1750  Solapur
# 1751  Solapur
# 1752  Solapur
# 1753  Solapur
# 1754  Solapur
# 1755  Solapur
# 1756  Solapur
# 1757  Solapur
# 1758  Solapur
# 1759  Solapur
#
# [1760 rows x 17 columns]

# %%
import matplotlib.pyplot as plt

# %%
forecast_plot = z[['dt_txt', 'main.temp', 'city']] # selecting required columns to plot

# %%
Avg_temp = forecast_plot.groupby(['dt_txt','city']).mean()['main.temp']
Avg_temp
# Out:
# dt_txt               city
# 2019-08-08 06:00:00  Agra          312.530
#                      Ahmedabad     300.790
#                      Allahabad     308.870
#                      Amritsar      311.210
#                      Aurangabad    296.340
#                      Bangalore     298.590
#                      Bhopal        301.840
#                      Chandigarh    304.560
#                      Chennai       307.460
#                      Coimbatore    297.850
#                      Delhi         309.020
#                      Dhanbad       300.520
#                      Faridabad     309.020
#                      Ghaziabad     309.440
#                      Guwahati      305.980
#                      Gwalior       311.770
#                      Howrah        302.240
#                      Hyderabad     301.720
#                      Indore        291.700
#                      Jabalpur      305.560
#                      Jaipur        306.580
#                      Jodhpur       309.900
#                      Kanpur        304.960
#                      Kolkata       302.240
#                      Kota          303.620
#                      Lucknow       305.210
#                      Ludhiana      314.350
#                      Madurai       301.480
#                      Meerut        309.410
#                      Mumbai        302.060
#                                     ...
# 2019-08-13 03:00:00  Guwahati      303.424
#                      Gwalior       303.124
#                      Howrah        303.824
#                      Hyderabad     297.624
#                      Indore        294.124
#                      Jabalpur      298.724
#                      Jaipur        301.624
#                      Jodhpur       301.424
#                      Kanpur        300.624
#                      Kolkata       303.824
#                      Kota          300.124
#                      Lucknow       301.024
#                      Ludhiana      305.024
#                      Madurai       301.924
#                      Meerut        305.424
#                      Mumbai        301.224
#                      Nagpur        300.124
#                      Nashik        295.824
#                      Patna         301.224
#                      Pune          295.224
#                      Raipur        299.224
#                      Rajkot        300.924
#                      Ranchi        299.324
#                      Solapur       298.624
#                      Srinagar      291.724
#                      Surat         301.124
#                      Thane         301.224
#                      Vadodara      301.224
#                      Varanasi      300.724
#                      Vijayawada    303.024
# Name: main.temp, Length: 1760, dtype: float64

# %%
#plotting average temperature at every 3 hrs duriation across all cities
fig, ax = plt.subplots(figsize=(20,10))
forecast_plot.groupby(['dt_txt','city']).mean()['main.temp'].unstack().plot(ax=ax)
ax.set_xlabel('dt_txt')
ax.set_ylabel('main.temp')
# Out:
# Text(0, 0.5, 'main.temp')
